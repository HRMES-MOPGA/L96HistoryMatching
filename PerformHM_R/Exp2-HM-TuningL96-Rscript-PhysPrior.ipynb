# %% [markdown]
# ## Libraries

# %%
mogp_dir <- "/gpfs7kw/linkhome/rech/genloc01/udu91zn/mogp_emulator"
## important to add "import warning" at MutliOutputGP.py

source('/gpfswork/rech/omr/udu91zn/HighTune_R/BuildEmulator/BuildEmulator.R')
source('/gpfswork/rech/omr/udu91zn/HighTune_R/HistoryMatching/HistoryMatching.R')
#source("HistoryMatching/impLayoutplot.R")
source('/gpfswork/rech/omr/udu91zn/HighTune_R/BuildEmulator/utils.R')

library(comprehenr)
library(caret)
library("future.apply") #important for parallel version of ImplausibilityMOGP function in HistoryMatching.R
# Out:
# far library : Modelization for Functional AutoRegressive processes
#
# version 0.6-4 (2014-12-07)
#
# Warning message:
# “package ‘fields’ was built under R version 3.6.3”Spam version 2.2-2 (2019-03-07) is loaded.
# Type 'help( Spam)' or 'demo( spam)' for a short introduction
# and overview of this package.
# Help for individual functions is also obtained by adding the
# suffix '.spam' to the function name, e.g. 'help( chol.spam)'.
#
# Attaching package: ‘spam’
#
# The following objects are masked from ‘package:base’:
#
#     backsolve, forwardsolve
#
# See https://github.com/NCAR/Fields for
#  an extensive vignette, other supplements and source code
# Warning message:
# “package ‘lhs’ was built under R version 3.6.3”Warning message:
# “package ‘mco’ was built under R version 3.6.3”Warning message:
# “package ‘mvtnorm’ was built under R version 3.6.3”Warning message:
# “package ‘ncdf4’ was built under R version 3.6.3”Warning message:
# “package ‘shape’ was built under R version 3.6.3”Warning message:
# “package ‘tensor’ was built under R version 3.6.3”This is loo version 2.1.0.
# **NOTE: As of version 2.0.0 loo defaults to 1 core but we recommend using as many as possible. Use the 'cores' argument or set options(mc.cores = NUM_CORES) for an entire session. Visit mc-stan.org/loo/news for details on other changes.
# Loading required package: lattice
# Loading required package: ggplot2
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Warning message:
# “package ‘future.apply’ was built under R version 3.6.3”Loading required package: future
# Warning message:
# “package ‘future’ was built under R version 3.6.3”
# Attaching package: ‘future’
#
# The following object is masked from ‘package:caret’:
#
#     cluster

# %% [markdown]
# # Read data

# %%
my_bounds <- data.frame(c(0, 2), c(0, 20), c(1, 20), c(1, 20))

# %%
set.seed(42)
inputs <- as.data.frame(2*maximinLHS(40, 4)-1)
inputs_unscaled <- rangeUnscale(inputs, my_bounds)
names(inputs) <- c('h','F','c','b')
names(inputs_unscaled) <- c('h','F','c','b')
inputs_unscaled
# Out:
#    h          F          c         b
# 1  0.52467315  4.3718870  4.229452  5.772260
# 2  0.70536254 12.9415213 13.898875  4.984930
# 3  1.69603016 10.4731313 16.877577  8.735142
# 4  1.51201010  5.1285443  9.641193  1.603373
# 5  1.58267595  6.1076001 11.308971 14.573699
# 6  0.89421304 15.1042130  7.555337  9.374006
# 7  1.34443719 18.0941908  9.057361 14.923850
# 8  1.79877661  0.5991453  6.722807  7.502141
# 9  0.92410114 17.5708722 16.473220 16.452886
# 10 1.40480899 11.8477242  8.324857 10.385997
# 11 0.39652475 13.6617128 13.010208 10.808676
# 12 0.81581691  6.6903299 14.463958 15.486020
# 13 0.77349177 14.3735908  2.390199 19.736526
# 14 0.97780270  7.6405944  5.231004 18.252274
# 15 1.49103124 10.8809191 19.985364 11.291125
# 16 1.73179323 16.0365121 10.879613  6.228657
# 17 0.26825652 16.8355503  4.402150  7.841889
# 18 0.67400607  8.9595938 18.229823  8.527204
# 19 0.45703698  1.3881247  9.437831 13.053177
# 20 1.01191443  9.8702367 12.316017  1.399847
# 21 1.99208664  5.6597893  3.161943 12.589861
# 22 0.59062578  2.8172316  3.443812  4.198895
# 23 1.89945811  3.7157198 15.610311  7.050812
# 24 0.33647159 14.6662882  7.691216 17.305053
# 25 1.16861291  1.8761982 19.382879 12.302243
# 26 1.22551893 13.0104094 13.743742 13.735214
# 27 1.29645320 19.1945669  5.508613  2.420364
# 28 0.12892355  4.6513926  1.735115 14.237011
# 29 0.02031819  7.0840598 11.767964  9.627296
# 30 1.06059435 12.3076525  2.441665 11.730777
# 31 0.09110624  3.0420778 15.778693 19.163830
# 32 1.92458307  9.1081791 17.476707 15.954037
# 33 0.15806423 19.9982539 12.438046  5.626624
# 34 1.63549461  8.0629431  5.899989  4.338071
# 35 1.13042951  2.0222961 10.388122 18.075896
# 36 1.35551766 15.9494268 18.741228  3.344497
# 37 0.41112673 11.2558470  1.253783  3.797761
# 38 0.22732865 17.0254831 18.049299 18.860187
# 39 0.60440849  0.4867314 14.987631  2.576999
# 40 1.80645293 18.5790231  6.380826 16.985472

# %%
write.csv(inputs_unscaled,"/gpfswork/rech/omr/udu91zn/HighTune_R/Data/JAMES/df_inputs_newPCA_PhysPrior_wave1.csv", row.names = FALSE)

# %%
set.seed(42)
                       
#Load outputs and select variables you want to keep
outputs <- read.csv("/gpfswork/rech/omr/udu91zn/HighTune_R/Data/JAMES/df_metrics_newPCA_PhysPrior_wave1.csv")
                         
#Add some noise (here no noise added)
N = nrow(inputs) #nb samples 
noise <- rnorm(N, 0, 0.5)
tData <- cbind(inputs, noise, outputs)
names(tData)[names(tData) == "noise"] <- "Noise"
                         
head(tData)
# Out:
#   h          F           c           b          Noise       pca_0
# 1 -0.4753268 -0.56281130 -0.66005764 -0.4976568  0.68547922  -5.613217
# 2 -0.2946375  0.29415213  0.35777631 -0.5805336 -0.28234909   6.909158
# 3  0.6960302  0.04731313  0.67132394 -0.1857745  0.18156421   2.155878
# 4  0.5120101 -0.48714557 -0.09040072 -0.9364871  0.31643130 -13.936713
# 5  0.5826760 -0.38923999  0.08515486  0.4288105  0.20213416  -5.544478
# 6 -0.1057870  0.51042130 -0.30996449 -0.1185257 -0.05306226  12.277960
#   pca_1      pca_2       pca_3      pca_4
# 1  2.6710207 -0.04301439 -1.5100246 -0.3912528
# 2  3.0346227 -0.60467748 -3.3268089 -1.2969888
# 3  5.0741323 -2.04826318 -2.1843899  2.1637270
# 4  4.4522212  3.01607374  0.9911436 -1.3297360
# 5  0.8785791 -1.50346329 -0.6208147 -0.2823825
# 6 -5.2619980  0.86533103 -2.0124434 -2.3632270

# %% [markdown]
# ### Training Emulators

# %%
#choices.new <- choices.default
#choices.new$lm.maxdf = 3 ### NOT WORKING
#choices.new$lm.tryFouriers=TRUE  ### NOT WORKING

# %%
TestEm <- BuildNewEmulators(tData,
                            HowManyEmulators = length(outputs),
                            meanFun = "fitted",
                            #kernel = c("Matern52"),
                            additionalVariables = names(tData)[1:4])  #important to put this line
                            #Choices = lapply(1:length(outputs), function(k) choices.new))
# Out:
# [1] "Max reduction is 4.66111105357057 using F"
# [1] "Max reduction is 0.645109344088585 using c"
# [1] "Max reduction is 0.726787794867733 using b"
# [1] "Max reduction is 0.214105522021229 using b"
# [1] "Max reduction is 0.403847895068548 using Three Way Interactions with b"
# [1] "Max reduction is 1.10008174082152 using h"
# [1] "Max reduction is 0.247818506283979 using b"
# [1] "Max reduction is 0.304114449281365 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = pca_0 ~ F + c + b + I(b^2) + I(b^3) + I(b^4) + h +
#     I(c * F) + I(b * F) + I(h * F) + I(b * c) + I(h * c) + I(h *
#     b) + I(b * c * F) + I(b * b * F) + I(b * h * F) + I(b * b *
#     c) + I(b * h * c) + I(b * h * b), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.50523 -0.93628  0.02788  1.18281  2.69567
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)    0.8319     0.6144   1.354 0.190799
# F             16.3030     0.9958  16.373 4.74e-13 ***
# c             -0.5999     0.9285  -0.646 0.525580
# b             -5.2069     1.6894  -3.082 0.005879 **
# I(b^2)         6.4131     4.2381   1.513 0.145870
# I(b^3)         6.2462     2.9052   2.150 0.043970 *
# I(b^4)       -14.6291     5.1534  -2.839 0.010148 *
# h              3.6155     0.8972   4.030 0.000657 ***
# I(c * F)      -2.2611     1.2109  -1.867 0.076575 .
# I(b * F)      -3.6392     0.9350  -3.892 0.000905 ***
# I(h * F)       5.4312     1.0195   5.327 3.25e-05 ***
# I(b * c)       7.1401     1.1353   6.289 3.86e-06 ***
# I(h * c)      -4.7583     1.0628  -4.477 0.000231 ***
# I(h * b)       0.5709     1.2891   0.443 0.662598
# I(b * c * F)   7.7189     2.0679   3.733 0.001313 **
# I(b * b * F)  -3.9638     2.2649  -1.750 0.095426 .
# I(b * h * F)  -2.0250     1.8998  -1.066 0.299180
# I(b * b * c) -13.8898     2.5464  -5.455 2.44e-05 ***
# I(b * h * c)   5.5796     2.3142   2.411 0.025649 *
# I(b * h * b)  -8.4206     2.8738  -2.930 0.008278 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.951 on 20 degrees of freedom
# Multiple R-squared:  0.9814,	Adjusted R-squared:  0.9638
# F-statistic: 55.66 on 19 and 20 DF,  p-value: 2.688e-13
#
# [1] "1 I(b * b * F)"
# [1] "2 I(b * h * F)"
# [1] "3 I(b * h * c)"
# [1] "4 I(h * c)"
# [1] "5 I(b * h * b)"
# [1] "6 I(h * b)"
# [1] "7 I(b * F)"
# [1] "8 I(h * F)"
# [1] "9 h"
# [1] "10 I(b * c * F)"
# [1] "11 I(b^4)"
# [1] "12 I(b^3)"
# [1] "13 I(b^2)"
# [1] "14 I(c * F)"
#
# Call:
# lm(formula = pca_0 ~ F + c + b + I(b * c) + I(b * b * c), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.9653 -2.4372  0.4294  2.1268  8.1290
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -0.2332     0.6579  -0.354 0.725167
# F             14.8781     1.1393  13.059 8.36e-15 ***
# c             -0.8498     1.6795  -0.506 0.616148
# b             -0.8343     1.1416  -0.731 0.469890
# I(b * c)       8.0832     2.0403   3.962 0.000361 ***
# I(b * b * c) -11.1853     3.8830  -2.881 0.006825 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.142 on 34 degrees of freedom
# Multiple R-squared:  0.8577,	Adjusted R-squared:  0.8368
# F-statistic: 40.99 on 5 and 34 DF,  p-value: 1.897e-13
#
# [1] "Max reduction is 1.42937884498258 using b"
# [1] "Max reduction is 0.891323170942649 using h"
# [1] "Max reduction is 1.64312158540536 using F"
# [1] "Max reduction is 0.237955852164534 using b"
# [1] "Max reduction is 1.18159845326645 using Three Way Interactions with b"
# [1] "Max reduction is 0.759539188303517 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = pca_1 ~ b + I(b^2) + h + F + c + I(h * b) + I(F *
#     b) + I(c * b) + I(F * h) + I(c * h) + I(c * F) + I(b * h *
#     b) + I(b * F * b) + I(b * c * b) + I(b * F * h) + I(b * c *
#     h) + I(b * c * F), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.1477 -0.9812  0.2475  0.9602  3.4052
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -1.5784     0.5322  -2.966 0.007133 **
# b             -8.2056     0.6400 -12.820 1.11e-11 ***
# I(b^2)         5.0063     1.2649   3.958 0.000668 ***
# h              6.4826     0.9460   6.853 6.97e-07 ***
# F             -6.5398     1.0463  -6.250 2.73e-06 ***
# c              0.8308     0.9601   0.865 0.396165
# I(h * b)      -4.2063     1.2316  -3.415 0.002480 **
# I(F * b)      -9.6068     0.9900  -9.704 2.08e-09 ***
# I(c * b)       4.3883     1.1423   3.842 0.000887 ***
# I(F * h)       7.6540     1.0356   7.391 2.14e-07 ***
# I(c * h)      -1.3642     1.1048  -1.235 0.229922
# I(c * F)      -0.9448     1.2385  -0.763 0.453652
# I(b * h * b)  -3.1725     2.8330  -1.120 0.274865
# I(b * F * b)   9.9612     2.3863   4.174 0.000394 ***
# I(b * c * b)  -5.6231     2.4926  -2.256 0.034356 *
# I(b * F * h)  -7.1326     2.0131  -3.543 0.001825 **
# I(b * c * h)   4.2907     2.3867   1.798 0.085952 .
# I(b * c * F)   3.1751     2.1213   1.497 0.148668
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.074 on 22 degrees of freedom
# Multiple R-squared:  0.9641,	Adjusted R-squared:  0.9363
# F-statistic: 34.73 on 17 and 22 DF,  p-value: 4.958e-12
#
# [1] "1 I(b * h * b)"
# [1] "2 I(b * c * F)"
# [1] "3 I(c * F)"
# [1] "4 I(b * c * h)"
# [1] "5 I(c * h)"
# [1] "6 I(b * c * b)"
# [1] "7 I(c * b)"
# [1] "8 c"
# [1] "9 I(b^2)"
# [1] "10 I(b * F * h)"
# [1] "11 I(b * F * b)"
# [1] "12 I(h * b)"
#
# Call:
# lm(formula = pca_1 ~ b + h + F + I(F * b) + I(F * h), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.4105 -1.8845 -0.4861  0.7645 18.7775
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.2019     0.7428   0.272 0.787457
# b            -7.6500     1.2970  -5.898 1.17e-06 ***
# h             5.3480     1.2912   4.142 0.000215 ***
# F            -2.8845     1.2948  -2.228 0.032624 *
# I(F * b)     -8.4612     2.1189  -3.993 0.000330 ***
# I(F * h)      6.4590     2.1758   2.969 0.005449 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.692 on 34 degrees of freedom
# Multiple R-squared:  0.7158,	Adjusted R-squared:  0.674
# F-statistic: 17.12 on 5 and 34 DF,  p-value: 1.894e-08
#
# [1] "Max reduction is 0.244328782955194 using b"
# [1] "Max reduction is 0.073031602052898 using b"
# [1] "Max reduction is 0.0524736958116763 using F"
# [1] "Max reduction is 0.230375343437639 using F"
# [1] "Max reduction is 0.165745145894965 using h"
# [1] "Max reduction is 0.190050755794722 using Three Way Interactions with b"
# [1] "Max reduction is 0.152849274334554 using c"
# [1] "Max reduction is 0.188318084836118 using h"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = pca_2 ~ b + I(b^2) + F + I(F^2) + h + I(h^2) + c +
#     I(F * b) + I(h * b) + I(c * b) + I(h * F) + I(c * F) + I(c *
#     h) + I(b * F * b) + I(b * h * b) + I(b * c * b) + I(b * h *
#     F) + I(b * c * F) + I(b * c * h), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.5882 -0.3498 -0.0243  0.4152  1.0260
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.92986    0.29391  -3.164 0.004883 **
# b            -1.55448    0.23655  -6.571 2.11e-06 ***
# I(b^2)        1.96083    0.47895   4.094 0.000565 ***
# F            -0.05007    0.41206  -0.122 0.904490
# I(F^2)        2.26654    0.47108   4.811 0.000106 ***
# h             0.20328    0.35053   0.580 0.568444
# I(h^2)       -1.72942    0.48567  -3.561 0.001958 **
# c            -1.08467    0.36660  -2.959 0.007764 **
# I(F * b)      1.38831    0.36405   3.814 0.001088 **
# I(h * b)      1.03635    0.46129   2.247 0.036112 *
# I(c * b)     -0.65819    0.42004  -1.567 0.132805
# I(h * F)     -2.46860    0.38216  -6.460 2.68e-06 ***
# I(c * F)     -0.84688    0.45929  -1.844 0.080069 .
# I(c * h)      1.13614    0.41326   2.749 0.012368 *
# I(b * F * b)  1.43518    0.95213   1.507 0.147357
# I(b * h * b)  0.15670    1.05171   0.149 0.883052
# I(b * c * b)  3.75367    0.97230   3.861 0.000974 ***
# I(b * h * F)  3.29895    0.83430   3.954 0.000783 ***
# I(b * c * F) -1.15090    0.78514  -1.466 0.158236
# I(b * c * h) -2.13596    0.87887  -2.430 0.024621 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.761 on 20 degrees of freedom
# Multiple R-squared:  0.9251,	Adjusted R-squared:  0.854
# F-statistic: 13.01 on 19 and 20 DF,  p-value: 1.951e-07
#
# [1] "1 I(h^2)"
# [1] "2 I(b * h * b)"
# [1] "3 I(b * F * b)"
# [1] "4 I(h * b)"
# [1] "5 I(b * c * h)"
# [1] "6 I(c * h)"
# [1] "7 I(b * c * F)"
# [1] "8 I(c * F)"
# [1] "9 I(b * c * b)"
# [1] "10 I(c * b)"
# [1] "11 c"
# [1] "12 I(F * b)"
# [1] "13 I(b * h * F)"
# [1] "14 I(b^2)"
#
# Call:
# lm(formula = pca_2 ~ b + F + I(F^2) + h + I(h * F), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.1038 -0.4919 -0.2097  0.7250  2.8537
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -1.0204     0.3291  -3.101 0.003867 **
# b            -1.5894     0.3805  -4.178 0.000194 ***
# F             0.5639     0.3796   1.486 0.146596
# I(F^2)        3.0281     0.7429   4.076 0.000260 ***
# h             0.1544     0.3801   0.406 0.687113
# I(h * F)     -1.7315     0.6373  -2.717 0.010285 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.376 on 34 degrees of freedom
# Multiple R-squared:  0.5838,	Adjusted R-squared:  0.5226
# F-statistic: 9.537 on 5 and 34 DF,  p-value: 9.372e-06
#
# [1] "Max reduction is 0.0563779478446935 using b"
# [1] "Max reduction is 0.150756325589378 using b"
# [1] "Max reduction is 0.0650904920783362 using h"
# [1] "Max reduction is 0.0449548220257154 using Three Way Interactions with b"
# [1] "Max reduction is 0.0657819198422827 using h"
# [1] "Max reduction is 0.0765090501424508 using F"
# [1] "Max reduction is 0.313198904044871 using F"
# [1] "Max reduction is 0.233431725228671 using c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = pca_3 ~ b + I(b^2) + h + I(h^2) + F + I(F^2) + c +
#     I(h * b) + I(F * b) + I(c * b) + I(F * h) + I(c * h) + I(c *
#     F) + I(b * h * b) + I(b * F * b) + I(b * c * b) + I(b * F *
#     h) + I(b * c * h) + I(b * c * F), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.34805 -0.34771  0.01947  0.35693  1.17116
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -1.80910    0.32255  -5.609 1.73e-05 ***
# b             0.89467    0.25961   3.446 0.002554 **
# I(b^2)        1.94358    0.52563   3.698 0.001425 **
# h            -1.16363    0.38470  -3.025 0.006691 **
# I(h^2)        1.72299    0.53301   3.233 0.004174 **
# F            -0.69262    0.45223  -1.532 0.141293
# I(F^2)        2.01224    0.51700   3.892 0.000905 ***
# c            -0.24612    0.40234  -0.612 0.547611
# I(h * b)     -2.16989    0.50625  -4.286 0.000360 ***
# I(F * b)      0.72532    0.39953   1.815 0.084483 .
# I(c * b)     -0.09356    0.46098  -0.203 0.841225
# I(F * h)      0.17535    0.41941   0.418 0.680331
# I(c * h)     -0.66142    0.45354  -1.458 0.160274
# I(c * F)     -1.61900    0.50406  -3.212 0.004376 **
# I(b * h * b)  3.66721    1.15422   3.177 0.004736 **
# I(b * F * b)  2.70239    1.04494   2.586 0.017646 *
# I(b * c * b)  1.00872    1.06707   0.945 0.355780
# I(b * F * h) -1.46319    0.91562  -1.598 0.125718
# I(b * c * h)  1.18872    0.96454   1.232 0.232083
# I(b * c * F)  1.85140    0.86167   2.149 0.044092 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8351 on 20 degrees of freedom
# Multiple R-squared:  0.8945,	Adjusted R-squared:  0.7943
# F-statistic: 8.925 on 19 and 20 DF,  p-value: 4.658e-06
#
# [1] "1 I(b * c * h)"
# [1] "2 I(c * h)"
# [1] "3 I(b * c * b)"
# [1] "4 I(c * b)"
# [1] "5 I(b * c * F)"
# [1] "6 I(c * F)"
# [1] "7 c"
# [1] "8 I(b * F * h)"
# [1] "9 I(F * h)"
# [1] "10 I(b * F * b)"
# [1] "11 I(F * b)"
# [1] "12 I(h^2)"
# [1] "13 I(b * h * b)"
# [1] "14 I(h * b)"
#
# Call:
# lm(formula = pca_3 ~ b + I(b^2) + h + F + I(F^2), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.8632 -0.6408 -0.0691  0.6694  3.7234
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.54760    0.42548  -3.637 0.000903 ***
# b            0.94098    0.41118   2.288 0.028448 *
# I(b^2)       2.10189    0.81924   2.566 0.014879 *
# h           -0.02386    0.41270  -0.058 0.954238
# F            0.31735    0.40970   0.775 0.443934
# I(F^2)       2.55297    0.81314   3.140 0.003489 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.49 on 34 degrees of freedom
# Multiple R-squared:  0.429,	Adjusted R-squared:  0.3451
# F-statistic:  5.11 on 5 and 34 DF,  p-value: 0.001338
#
# [1] "Max reduction is 0.00979136778765044 using h"
# [1] "Max reduction is 0.0121710332944278 using c"
# [1] "Max reduction is 0.106593679361093 using F"
# [1] "Noise fitted, stopping algorithm"
#
# Call:
# lm(formula = pca_4 ~ h + c + F + I(c * h) + I(F * h) + I(F *
#     c), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.3422 -0.9027  0.0196  0.8140  4.0396
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.0471     0.2463  -0.191   0.8495
# h            -0.5203     0.4272  -1.218   0.2318
# c             0.2323     0.4263   0.545   0.5895
# F             0.4958     0.4275   1.160   0.2545
# I(c * h)      1.3570     0.7360   1.844   0.0742 .
# I(F * h)     -0.6615     0.7260  -0.911   0.3688
# I(F * c)      1.8345     0.8119   2.260   0.0306 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.549 on 33 degrees of freedom
# Multiple R-squared:  0.2785,	Adjusted R-squared:  0.1474
# F-statistic: 2.123 on 6 and 33 DF,  p-value: 0.07687
#
# [1] "1 I(F * h)"
#
# Call:
# lm(formula = pca_4 ~ h + c + F + I(c * h) + I(F * c), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.3048 -0.9894 -0.0560  0.7484  4.0775
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.03812    0.24551  -0.155   0.8775
# h           -0.48088    0.42391  -1.134   0.2646
# c            0.25044    0.42481   0.590   0.5594
# F            0.52953    0.42482   1.246   0.2211
# I(c * h)     1.30819    0.73225   1.787   0.0829 .
# I(F * c)     1.93864    0.80179   2.418   0.0211 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.545 on 34 degrees of freedom
# Multiple R-squared:  0.2604,	Adjusted R-squared:  0.1516
# F-statistic: 2.394 on 5 and 34 DF,  p-value: 0.0579

# %%
tDisc <- rep(0, length(outputs))
tObs <- read.csv("/gpfswork/rech/omr/udu91zn/HighTune_R/Data/JAMES/df_obs_nonoise_newPCA_PhysPrior_wave1.csv")
tObs <- as.vector(t(tObs))
tObsErr <- rep(0, length(outputs))

# %% [markdown]
# ## LOO

# %%
cands <- names(tData)[1:4]

# %%
tLOOs <- LOO.plot(Emulators = TestEm, which.emulator = 1, ParamNames = cands, Obs = tObs[1], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm, which.emulator = 2, ParamNames = cands, Obs = tObs[2], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm, which.emulator = 3, ParamNames = cands, Obs = tObs[3], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm, which.emulator = 4, ParamNames = cands, Obs = tObs[4], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm, which.emulator = 5, ParamNames = cands, Obs = tObs[5], ObsErr = 0.)#tLOOs <-
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %% [markdown]
# ## History Matching
# * Observations discrepancy variances in *tDisc* (here sets to 0)
# * Observations errors in *tObsErr* (here set to 0)

# %%
future::availableCores()
# Out:
# Slurm
#    20

# %%
set.seed(42)
sample_size <- 1000000
nparam <- length(names(TestEm$fitting.elements$Design))
Xp <- as.data.frame(2*randomLHS(sample_size, nparam)-1)
names(Xp) <- names(TestEm$fitting.elements$Design)

# %%
system.time(Timps <- ImplausibilityMOGP(NewData=Xp, Emulator=TestEm, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr))
# Out:
#    user  system elapsed
#  18.739  11.492   5.085

# %%
ImpData_wave1 = cbind(Xp, Timps)
print(object.size(ImpData_wave1), units="Mb")
# Out:
# 68.7 Mb

# %%
VarNames <- names(Xp)
valmax = 0 #how many outputs can be above the implausibility cut off?
cutoff_vec <- 3 #the implausibility cut off

param.def = data.frame(h=c(1), F=c(10), c=c(10),b=c(10)) #the default parameters of the model (on [-1,1])
param.defaults.norm = rangeScale(param.def, my_bounds, range(-1,1))
print(param.defaults.norm)
# Out:
#   h F           c           b
# 1 0 0 -0.05263158 -0.05263158

# %%
ImpListM1 = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave1, nEms=TestEm$mogp$n_emulators, whichMax=valmax+1)
NROY1 <- which(rowSums(Timps <= cutoff_vec[1]) >= TestEm$mogp$n_emulators -valmax)
ratio1 <- length(NROY1)/dim(Xp)[1]
ratio1
# Out:
# [1] 0.255731

# %% [markdown]
# #### 40 samples for training, 1 000 000 points for test

# %%
imp.layoutm11(ImpListM1,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",length(NROY1)/dim(Xp)[1],sep=""), side=1)
# Out:
# plot without title

# %%
indminImp <- order(apply(Timps[NROY1,], 1, FUN=max))
rangeUnscale(Xp[NROY1[indminImp[1:100]],], my_bounds)
# Out:
#        h         F         c         b
# 688704 1.2576889  9.973211 10.709672 11.007388
# 107103 0.5448344 10.674149 15.416740  7.492420
# 741921 1.2780829  9.889589 10.179163 10.839390
# 149202 1.0886827  9.846963 11.004472 10.411268
# 217813 0.8661486  9.360680 10.152049  9.126773
# 436583 0.4337229 10.859025 15.519424  6.888281
# 293335 1.1378929  9.636945 11.334472 10.978092
# 502165 0.7727952  9.327127 11.004162  8.155156
# 306680 1.1946918  9.562286  9.750473 10.910835
# 396048 0.7433388  9.317200 10.071870  7.885081
# 761539 1.2537666  9.833499 11.057827 10.697003
# 551052 0.8795084  9.609472 11.777712  9.652328
# 367498 1.0738054  9.321042  9.907942 10.351496
# 400963 1.2607873  9.766281 11.093333 10.652084
# 179137 0.8997057  9.209573 10.411923  9.172199
# 6899   0.9997803  9.205327 10.282394  9.573764
# 52497  1.1578690  9.934658 10.858748 10.345401
# 518814 1.1000120  9.365041 10.798115 10.520587
# 491706 0.4813417 10.804904 15.266186  7.370736
# 302869 0.7579129  9.600908 10.342610  8.057442
# 165690 1.0835924  9.674288 10.962972 10.572794
# 191881 1.2013634  9.956227 11.227614 11.113830
# 637505 1.0863070  9.724158 11.570798 10.834094
# 890576 0.5716088 10.866915 15.700486  7.690321
# 122460 0.9268507  9.242538 11.078074  9.268095
# 597749 1.0417259  9.546305 10.158052  9.906462
# 955040 1.1138880  9.812244 10.260654 10.445134
# 77049  0.7134136  9.718704 11.209299  7.893471
# 361079 1.0162871  9.055921 10.113516  9.401090
# 235251 0.5180592 10.780543 15.590654  7.243998
# ...    ...       ...       ...       ...
# 448204 0.9678093  9.468343 10.915762 10.165605
# 634694 0.4296422 11.453148 16.184247  7.018455
# 655159 1.2707150  9.777745  9.827798 10.725731
# 502801 1.0176360  9.289966  9.824533  9.796023
# 566546 0.5682837 10.924273 15.986362  8.128625
# 245680 0.8440497  9.694276 12.132224  9.576086
# 761683 0.3704124 10.971752 15.518967  6.408770
# 542962 1.0695926  9.365015 11.381683  9.864970
# 887353 1.0652847  9.436127 12.321168 10.262401
# 206826 0.8025302  9.147646  9.743781  7.887739
# 970549 0.6779681 10.387525  8.897943  7.612366
# 703875 0.8716087  9.145180  9.593880  8.477890
# 965604 0.7108571  9.887174  9.009184  7.737388
# 734172 0.7376061  9.434712  9.627029  8.435442
# 757121 0.8876893 10.056084 12.011553  9.562669
# 540074 0.8842895  9.388408 10.714439  8.817350
# 649391 0.9952771 10.023204 11.746369 10.316546
# 258343 1.0429970  9.350795  9.731666 10.074175
# 808135 0.7153945  9.789781  9.021916  7.705216
# 51260  1.2590855  9.669167 11.656017 10.453554
# 531330 0.8915345  9.745306  9.924459  8.974281
# 773854 0.6295700 10.420839 14.894368  7.904621
# 289176 0.9316298  9.586782 12.103207 10.050700
# 871177 1.1132936  9.021295 10.241859  9.957213
# 355196 0.5904029  9.648970 10.590561  7.565192
# 623313 0.7417683  9.806172 11.554356  8.587667
# 694776 0.5522732 10.148631 11.486975  7.014008
# 404555 0.6542802 10.619633 14.624927  8.114043
# 664773 1.2539396  9.679047 10.275300 11.291448
# 550662 1.0388201  9.209669 11.316985 10.088281

# %%
length(NROY1)
# Out:
# [1] 255731

# %% [markdown]
# # Wave2

# %%
40/ratio1
# Out:
# [1] 156.4144

# %%
set.seed(42)

designpoints <- data.frame()

while (nrow(designpoints) <= 40) {
        tmp <- as.data.frame(2*maximinLHS(ceil(40/ratio1), 4)-1)
        names(tmp) <- names(TestEm$fitting.elements$Design)
        imps_tmp <- ImplausibilityMOGP(NewData=tmp, Emulator=TestEm, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
        NROYtmp <- which(rowSums(imps_tmp <= cutoff_vec[1]) >= TestEm$mogp$n_emulators -valmax)
        selectionP <- tmp[NROYtmp,]
        row.names(selectionP) <- NULL ## to avoid double index
        designpoints <- rbind(designpoints,selectionP)
        print(nrow(designpoints))
        flush.console()
        } 

designpoints <- designpoints[sample(nrow(designpoints),40),]

designpoints_denorm <- rangeUnscale(designpoints, my_bounds)
# Out:
# [1] 47

# %%
designpoints_denorm
# Out:
#    h          F         c         b
# 6  1.28964143 11.854978 12.741437 12.674857
# 31 0.01944759  8.165050 19.757955  9.670599
# 23 1.36360342  6.766776  6.983383 18.653007
# 10 0.92660462  8.757895 16.058709  5.461294
# 11 0.91582362 13.266182  9.702212 14.320167
# 13 1.14021912 15.454072 16.940174  6.177231
# 14 0.95553505 11.374741 12.467332  8.925073
# 38 1.30036691 10.034730 17.924207 11.529042
# 47 1.20451421 10.213341  3.046712 15.473119
# 43 0.55259659  9.573872 17.665088 15.185457
# 21 0.13957347  8.630489 13.691541 13.347292
# 24 0.78165857 11.321304  2.566000  7.800000
# 18 1.66167730 10.093679 15.525924 15.955648
# 41 1.28303886 15.134808 12.220463 18.203660
# 36 1.09716548  5.652721  1.602761  6.823264
# 34 0.36918697 13.802060  3.964443 13.265322
# 29 1.02919715  8.803548 13.921485 19.149224
# 20 0.40935676 15.377376 15.499071  7.657851
# 2  0.32990871 12.070403 17.261747  3.522656
# 45 0.90240072 15.706385 19.776017  8.724592
# 22 1.76172622 14.039236  1.904310 14.917176
# 33 0.24502606 16.587160 19.219421 13.831899
# 40 1.25561230  7.086137 10.435401 12.412167
# 27 0.80951870 14.910193 15.087437 12.237563
# 1  1.31831258  9.275256 15.169022  6.465630
# 32 0.06907163 12.261555 15.282306  3.048145
# 26 1.47332511 18.694078 18.715559  9.731858
# 7  1.44407390 12.778874 14.332431  8.313504
# 39 1.98763873  9.346555 19.377386 13.765976
# 44 0.76249618  8.528566  7.460138  5.658955
# 30 1.83794687  9.466566  7.156991 13.482914
# 4  0.63146423  7.404577  2.579942 15.076213
# 42 1.56693410 10.770566 19.623726 19.685282
# 5  0.44254732  9.688647  4.756693 10.729952
# 15 1.80944946  8.297196  8.937825 17.664115
# 8  1.38959959  8.060984  5.160923 11.007862
# 12 1.71068202 14.492917 17.350555 16.674085
# 16 1.59124889 14.177702 16.451370 11.851973
# 37 0.17739683 10.643781  1.263236  7.521308
# 35 1.72233923  6.289491  1.845063 18.415628

# %%
write.csv(designpoints_denorm,"/gpfswork/rech/omr/udu91zn/HighTune_R/Data/JAMES/exp_TuningL94_newPCA_PhysPrior_wave2.csv", row.names = FALSE)

# %%
inputs <- designpoints

#Load outputs and select variables you want to keep
outputs <- read.csv("/gpfswork/rech/omr/udu91zn/HighTune_R/Data/JAMES/df_metrics_newPCA_PhysPrior_wave2.csv")
                         
#Add some noise (here no noise added)
set.seed(42)

N = nrow(inputs) #nb samples 
noise <- rnorm(N, 0, 0.5)
tData <- cbind(inputs, noise, outputs)
names(tData)[names(tData) == "noise"] <- "Noise"
                         
head(tData)
# Out:
#    h           F          c           b           Noise       pca_0
# 6   0.28964143  0.1854978  0.23594076  0.22893233  0.68547922  4.8418942
# 31 -0.98055241 -0.1834950  0.97452162 -0.08730539 -0.28234909 -6.4069105
# 23  0.36360342 -0.3233224 -0.37017021  0.85821124  0.18156421 -4.1559692
# 10 -0.07339538 -0.1242105  0.58512723 -0.53039014  0.31643130  0.6306411
# 11 -0.08417638  0.3266182 -0.08397769  0.40212286  0.20213416  5.0123568
# 13  0.14021912  0.5454072  0.67791308 -0.45502829 -0.05306226 10.8820886
#    pca_1     pca_2      pca_3      pca_4
# 6  -3.073250 -1.7846739 -1.3102134 -0.42261514
# 31 -5.422896 -3.9671237  2.6195711  1.24437996
# 23 -1.550541 -2.2360357 -0.2715580  0.05312133
# 10  6.475282 -0.8236635 -2.8356508  3.39273912
# 11 -6.536052 -0.7080026 -0.1296571  0.15977472
# 13  4.544147 -2.0421568 -3.0063841 -0.53456001

# %%
TestEm2 <- BuildNewEmulators(tData,
                            HowManyEmulators = length(outputs),
                            meanFun = "fitted",
                            #kernel = c("Matern52"),
                            additionalVariables = names(tData)[1:4])  #important to put this line

                            #Choices = lapply(1:length(outputs),
                            #                   function(k) choices.new),
# Out:
# [1] "Max reduction is 2.37543724360361 using F"
# [1] "Max reduction is 0.141587672809496 using b"
# [1] "Max reduction is 0.266530177833769 using h"
# [1] "Max reduction is 0.289880875220958 using c"
# [1] "Max reduction is 0.254737988491677 using h"
# [1] "Max reduction is 0.334393435912907 using Three Way Interactions with h"
# [1] "Max reduction is 0.0776909676939672 using b"
# [1] "Max reduction is 0.147592497765506 using Three Way Interactions with b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = pca_0 ~ F + b + I(b^2) + h + I(h^2) + c + I(b *
#     F) + I(h * F) + I(c * F) + I(h * b) + I(c * b) + I(c * h) +
#     I(h * b * F) + I(h * h * F) + I(h * c * F) + I(h * h * b) +
#     I(h * c * b) + I(h * c * h) + I(b * b * F) + I(b * c * F) +
#     I(b * h * b) + I(b * c * b), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.32322 -0.29352  0.00108  0.22317  1.39896
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)    1.3473     0.3424   3.935 0.001068 **
# F             20.2838     1.3428  15.106 2.77e-11 ***
# b             -4.7164     0.7179  -6.569 4.77e-06 ***
# I(b^2)         1.9276     1.4109   1.366 0.189650
# h              2.9081     0.5982   4.862 0.000147 ***
# I(h^2)        -3.5329     1.0373  -3.406 0.003364 **
# c             -4.3237     0.6543  -6.609 4.43e-06 ***
# I(b * F)      -2.4167     2.2765  -1.062 0.303278
# I(h * F)      -3.3955     1.6821  -2.019 0.059582 .
# I(c * F)       0.3499     1.0128   0.345 0.733981
# I(h * b)       0.1268     1.7616   0.072 0.943451
# I(c * b)       0.4039     1.3102   0.308 0.761638
# I(c * h)      -1.7565     0.8024  -2.189 0.042839 *
# I(h * b * F)  20.1537     4.6877   4.299 0.000486 ***
# I(h * h * F) -12.6503     2.9738  -4.254 0.000536 ***
# I(h * c * F)  -0.1143     1.7272  -0.066 0.948027
# I(h * h * b)   7.0927     2.0194   3.512 0.002672 **
# I(h * c * b)  -2.6377     3.1212  -0.845 0.409798
# I(h * c * h)   3.9787     1.5756   2.525 0.021795 *
# I(b * b * F) -11.8369     4.3004  -2.752 0.013597 *
# I(b * c * F)   2.5313     2.4880   1.017 0.323240
# I(b * h * b)  -4.0001     2.1814  -1.834 0.084261 .
# I(b * c * b)   5.8776     2.8866   2.036 0.057624 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8426 on 17 degrees of freedom
# Multiple R-squared:  0.9862,	Adjusted R-squared:  0.9683
# F-statistic:  55.1 on 22 and 17 DF,  p-value: 8.907e-12
#
# [1] "1 I(h * c * F)"
# [1] "2 I(b * c * F)"
# [1] "3 I(c * F)"
# [1] "4 I(b * h * b)"
# [1] "5 I(b * b * F)"
# [1] "6 I(b * c * b)"
# [1] "7 I(h * c * h)"
# [1] "8 I(h * c * b)"
# [1] "9 I(c * b)"
# [1] "10 I(b^2)"
# [1] "11 I(h * h * F)"
# [1] "12 I(h * F)"
# [1] "13 I(h * b * F)"
# [1] "14 I(b * F)"
# [1] "15 I(h * h * b)"
# [1] "16 I(c * h)"
# [1] "17 I(h * b)"
#
# Call:
# lm(formula = pca_0 ~ F + b + h + I(h^2) + c, data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.1677 -0.5706  0.1805  0.9505  3.1147
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   1.8309     0.3792   4.828 2.87e-05 ***
# F            13.7145     0.8776  15.628  < 2e-16 ***
# b            -3.1237     0.6022  -5.187 9.83e-06 ***
# h             2.1996     0.5120   4.296 0.000137 ***
# I(h^2)       -2.0478     0.8766  -2.336 0.025521 *
# c            -1.3604     0.4251  -3.201 0.002970 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.56 on 34 degrees of freedom
# Multiple R-squared:  0.9052,	Adjusted R-squared:  0.8912
# F-statistic: 64.92 on 5 and 34 DF,  p-value: < 2.2e-16
#
# [1] "Max reduction is 0.316916770137073 using b"
# [1] "Max reduction is 1.14878723203938 using h"
# [1] "Max reduction is 0.97372211166381 using F"
# [1] "Max reduction is 0.502217136420088 using b"
# [1] "Max reduction is 0.0879765446464595 using c"
# [1] "Max reduction is 0.084248481548522 using Three Way Interactions with b"
# [1] "Noise fitted, stopping algorithm"
#
# Call:
# lm(formula = pca_1 ~ b + I(b^2) + h + F + c + I(h * b) + I(F *
#     b) + I(c * b) + I(F * h) + I(c * h) + I(c * F) + I(b * h *
#     b) + I(b * F * b) + I(b * c * b) + I(b * F * h) + I(b * c *
#     h) + I(b * c * F), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.38448 -0.23571 -0.04203  0.26484  3.12759
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -1.2305     0.2680  -4.592 0.000142 ***
# b             -7.8096     0.6986 -11.179 1.53e-10 ***
# I(b^2)         4.4599     1.3191   3.381 0.002690 **
# h              5.1278     0.5583   9.185 5.54e-09 ***
# F             -7.4750     1.0676  -7.001 5.01e-07 ***
# c              0.7605     0.4594   1.655 0.112052
# I(h * b)      -6.3810     1.2869  -4.958 5.83e-05 ***
# I(F * b)      -0.6106     2.3284  -0.262 0.795581
# I(c * b)      -3.3287     1.1759  -2.831 0.009728 **
# I(F * h)       2.7098     1.4095   1.923 0.067583 .
# I(c * h)       1.4319     0.7112   2.013 0.056487 .
# I(c * F)       1.2000     1.1352   1.057 0.301947
# I(b * h * b)   3.3386     1.7492   1.909 0.069436 .
# I(b * F * b)   1.8145     4.1196   0.440 0.663902
# I(b * c * b)   3.8709     2.2816   1.697 0.103876
# I(b * F * h)  -5.0333     4.3036  -1.170 0.254689
# I(b * c * h)  -1.6985     1.9263  -0.882 0.387443
# I(b * c * F)  -2.0517     2.6856  -0.764 0.453013
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.007 on 22 degrees of freedom
# Multiple R-squared:  0.9663,	Adjusted R-squared:  0.9403
# F-statistic: 37.15 on 17 and 22 DF,  p-value: 2.463e-12
#
# [1] "1 I(b * F * b)"
# [1] "2 I(b * c * h)"
# [1] "3 I(b * c * F)"
# [1] "4 I(c * F)"
# [1] "5 I(b * c * b)"
# [1] "6 I(b * F * h)"
# [1] "7 I(c * b)"
# [1] "8 I(c * h)"
# [1] "9 I(F * h)"
# [1] "10 I(b * h * b)"
# [1] "11 I(F * b)"
# [1] "12 I(b^2)"
#
# Call:
# lm(formula = pca_1 ~ b + h + F + c + I(h * b), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.8047 -0.9116 -0.1860  0.6226  4.6917
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.3891     0.3262  -1.193   0.2411
# b            -6.9214     0.6318 -10.956 1.07e-12 ***
# h             5.8995     0.5632  10.475 3.51e-12 ***
# F            -7.1099     0.9277  -7.664 6.56e-09 ***
# c             1.1137     0.4440   2.508   0.0171 *
# I(h * b)     -3.5569     1.1254  -3.161   0.0033 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.65 on 34 degrees of freedom
# Multiple R-squared:  0.8602,	Adjusted R-squared:  0.8397
# F-statistic: 41.86 on 5 and 34 DF,  p-value: 1.403e-13
#
# [1] "Max reduction is 0.081320063966789 using b"
# [1] "Max reduction is 0.0943582694905548 using F"
# [1] "Max reduction is 0.10420857182929 using c"
# [1] "Max reduction is 0.125176264524188 using h"
# [1] "Max reduction is 0.0957639908926889 using h"
# [1] "Max reduction is 0.0596197596071641 using Three Way Interactions with h"
# [1] "Max reduction is 0.0691858921853044 using F"
# [1] "Noise fitted, stopping algorithm"
#
# Call:
# lm(formula = pca_2 ~ b + F + I(F^2) + c + h + I(h^2) + I(F *
#     b) + I(c * b) + I(h * b) + I(c * F) + I(h * F) + I(h * c) +
#     I(h * F * b) + I(h * c * b) + I(h * h * b) + I(h * c * F) +
#     I(h * h * F) + I(h * h * c), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.97417 -0.16174 -0.03474  0.19081  0.78876
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -1.10183    0.13595  -8.105 6.68e-08 ***
# b            -1.25655    0.24343  -5.162 4.09e-05 ***
# F             0.33774    0.52340   0.645 0.525734
# I(F^2)        3.73438    1.29764   2.878 0.009005 **
# c            -0.66285    0.22429  -2.955 0.007553 **
# h             0.28878    0.25380   1.138 0.267999
# I(h^2)       -1.78364    0.42264  -4.220 0.000384 ***
# I(F * b)      1.14267    0.79109   1.444 0.163377
# I(c * b)      0.06446    0.37336   0.173 0.864584
# I(h * b)      0.89656    0.52793   1.698 0.104229
# I(c * F)     -1.60206    0.64416  -2.487 0.021368 *
# I(h * F)     -2.99611    0.82720  -3.622 0.001598 **
# I(h * c)     -0.40980    0.31625  -1.296 0.209111
# I(h * F * b)  4.03225    2.05413   1.963 0.063029 .
# I(h * c * b)  0.03346    0.87092   0.038 0.969714
# I(h * h * b)  1.19952    0.78247   1.533 0.140209
# I(h * c * F) -0.81834    0.86345  -0.948 0.354036
# I(h * h * F)  1.88590    1.28990   1.462 0.158530
# I(h * h * c)  0.50613    0.57030   0.887 0.384872
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4502 on 21 degrees of freedom
# Multiple R-squared:  0.9064,	Adjusted R-squared:  0.8262
# F-statistic:  11.3 on 18 and 21 DF,  p-value: 4.468e-07
#
# [1] "1 I(h * c * b)"
# [1] "2 I(h * h * c)"
# [1] "3 I(h * h * b)"
# [1] "4 I(h * h * F)"
# [1] "5 I(F^2)"
# [1] "6 I(h * c * F)"
# [1] "7 I(c * F)"
# [1] "8 I(c * b)"
# [1] "9 I(h * F * b)"
# [1] "10 I(h * c)"
# [1] "11 I(F * b)"
# [1] "12 I(h * b)"
# [1] "13 I(h^2)"
#
# Call:
# lm(formula = pca_2 ~ b + F + c + h + I(h * F), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.76883 -0.38053 -0.04891  0.44086  1.29180
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -1.3361     0.1345  -9.934 1.38e-11 ***
# b            -1.0153     0.2877  -3.529 0.001220 **
# F             2.0379     0.4236   4.811 3.01e-05 ***
# c            -0.7431     0.2020  -3.679 0.000803 ***
# h             0.4198     0.2579   1.628 0.112846
# I(h * F)     -2.2088     0.7574  -2.916 0.006233 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7497 on 34 degrees of freedom
# Multiple R-squared:  0.5798,	Adjusted R-squared:  0.518
# F-statistic: 9.381 on 5 and 34 DF,  p-value: 1.093e-05
#
# [1] "Max reduction is 0.245829442210064 using b"
# [1] "Max reduction is 0.262690590513811 using h"
# [1] "Max reduction is 0.210216492572174 using h"
# [1] "Max reduction is 0.0977440932064206 using h"
# [1] "Max reduction is 0.100344174624219 using F"
# [1] "Max reduction is 0.0365643052750875 using c"
# [1] "Noise fitted, stopping algorithm"
#
# Call:
# lm(formula = pca_3 ~ b + h + I(h^2) + I(h^3) + F + c + I(h *
#     b) + I(F * b) + I(c * b) + I(F * h) + I(c * h) + I(c * F),
#     data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.71015 -0.27265  0.08912  0.27369  0.99881
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.70884    0.15617 -10.943 1.99e-11 ***
# b            2.21178    0.24797   8.919 1.56e-09 ***
# h            1.03057    0.52595   1.959 0.060458 .
# I(h^2)       2.71548    0.39845   6.815 2.55e-07 ***
# I(h^3)      -3.41627    0.74740  -4.571 9.65e-05 ***
# F            0.16300    0.42193   0.386 0.702293
# c           -0.47081    0.18936  -2.486 0.019388 *
# I(h * b)    -2.18239    0.49962  -4.368 0.000166 ***
# I(F * b)     2.32187    0.93540   2.482 0.019571 *
# I(c * b)     0.36590    0.47574   0.769 0.448508
# I(F * h)    -0.98306    0.69985  -1.405 0.171519
# I(c * h)     0.20080    0.32588   0.616 0.542945
# I(c * F)    -0.07146    0.52332  -0.137 0.892400
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.592 on 27 degrees of freedom
# Multiple R-squared:  0.8984,	Adjusted R-squared:  0.8533
# F-statistic:  19.9 on 12 and 27 DF,  p-value: 2.383e-10
#
# [1] "1 I(c * F)"
# [1] "2 I(c * h)"
# [1] "3 I(c * b)"
# [1] "4 I(F * h)"
# [1] "5 c"
# [1] "6 I(h^3)"
# [1] "7 I(F * b)"
#
# Call:
# lm(formula = pca_3 ~ b + h + I(h^2) + F + I(h * b), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.71432 -0.38232  0.01615  0.36269  1.90903
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.65541    0.20359  -8.131 1.75e-09 ***
# b            2.47821    0.32366   7.657 6.70e-09 ***
# h           -1.08190    0.30293  -3.571  0.00108 **
# I(h^2)       2.49473    0.54424   4.584 5.91e-05 ***
# F            0.01888    0.43019   0.044  0.96524
# I(h * b)    -2.10445    0.66892  -3.146  0.00343 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8387 on 34 degrees of freedom
# Multiple R-squared:  0.7432,	Adjusted R-squared:  0.7055
# F-statistic: 19.68 on 5 and 34 DF,  p-value: 3.543e-09
#
# [1] "Max reduction is 0.0606340479946328 using h"
# [1] "Max reduction is 0.0435640515584701 using F"
# [1] "Max reduction is 0.0626396629371746 using c"
# [1] "Max reduction is 0.126088107905378 using b"
# [1] "Noise fitted, stopping algorithm"
#
# Call:
# lm(formula = pca_4 ~ h + F + c + b + I(F * h) + I(c * h) + I(b *
#     h) + I(c * F) + I(b * F) + I(b * c), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.03106 -0.44921 -0.04493  0.30199  2.53208
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.08763    0.21383   0.410  0.68496
# h           -1.09160    0.41126  -2.654  0.01277 *
# F           -2.26028    0.71865  -3.145  0.00382 **
# c            1.01814    0.31849   3.197  0.00335 **
# b            0.72073    0.42309   1.703  0.09917 .
# I(F * h)    -2.87584    1.10419  -2.604  0.01436 *
# I(c * h)     1.46342    0.53853   2.717  0.01098 *
# I(b * h)    -0.34618    0.73237  -0.473  0.63998
# I(c * F)    -0.43762    0.88111  -0.497  0.62316
# I(b * F)     4.80417    1.60661   2.990  0.00563 **
# I(b * c)    -1.97851    0.81699  -2.422  0.02193 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.017 on 29 degrees of freedom
# Multiple R-squared:  0.5518,	Adjusted R-squared:  0.3973
# F-statistic:  3.57 on 10 and 29 DF,  p-value: 0.003514
#
# [1] "1 I(b * h)"
# [1] "2 I(c * F)"
# [1] "3 I(F * h)"
# [1] "4 I(c * h)"
# [1] "5 I(b * c)"
#
# Call:
# lm(formula = pca_4 ~ h + F + c + b + I(b * F), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.4427 -0.5751 -0.1444  0.1648  2.9736
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.0875     0.2076   0.421  0.67608
# h            -1.0797     0.3710  -2.911  0.00632 **
# F            -1.8430     0.6764  -2.725  0.01009 *
# c             0.5490     0.3087   1.779  0.08426 .
# b             0.4697     0.4462   1.053  0.29991
# I(b * F)      2.4510     1.3536   1.811  0.07903 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.143 on 34 degrees of freedom
# Multiple R-squared:  0.3361,	Adjusted R-squared:  0.2385
# F-statistic: 3.443 on 5 and 34 DF,  p-value: 0.01266

# %%
tObs2 <- read.csv("/gpfswork/rech/omr/udu91zn/HighTune_R/Data/JAMES/df_obs_nonoise_newPCA_PhysPrior_wave1.csv")
tObs2 <- as.vector(t(tObs2)) ############## no chnage in obs in waves

# %%
cands <- names(tData)[1:4]
tLOOs <- LOO.plot(Emulators = TestEm2, which.emulator = 1, ParamNames = cands, Obs = tObs2[1], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm2, which.emulator = 2, ParamNames = cands, Obs = tObs2[2], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm2, which.emulator = 3, ParamNames = cands, Obs = tObs2[3], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm2, which.emulator = 4, ParamNames = cands, Obs = tObs2[4], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm2, which.emulator = 5, ParamNames = cands, Obs = tObs2[5], ObsErr = 0.)#tLOOs <-
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
Timps2 <- matrix(rep(t(Timps),1), ncol=ncol(Timps), byrow=TRUE)
system.time(Timps2[NROY1,] <- ImplausibilityMOGP(NewData=Xp[NROY1,], Emulator=TestEm2, Discrepancy=tDisc, Obs=tObs2, ObsErr=tObsErr))
# Out:
#    user  system elapsed
#   6.341   8.781   2.508

# %%
#tracemem(Timps2) == tracemem(Timps)

# %%
ImpData_wave2 = cbind(Xp, Timps2)

# %%
valmax2 = 0 #how many outputs can be above the implausibility cut off?
ImpListM2 = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave2, nEms=TestEm2$mogp$n_emulators, whichMax=valmax2+1)
NROY2 <- which(rowSums(Timps2 <= cutoff_vec[1]) >= TestEm2$mogp$n_emulators -valmax2)
ratio2 <- length(NROY2)/dim(Xp)[1]
ratio2
# Out:
# [1] 0.031812

# %%
imp.layoutm11(ImpListM2,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",length(NROY2)/dim(Xp)[1],sep=""), side=1)
# Out:
# plot without title

# %%
indminImp2 <- order(apply(Timps2[NROY2,], 1, FUN=max))
rangeUnscale(Xp[NROY2[indminImp2[1:10]],], my_bounds)
# Out:
#        h        F        c        b
# 36508  1.056688 11.11882 13.69855 10.38706
# 864936 1.093024 11.11962 13.59558 10.54167
# 528471 1.065250 11.12748 13.96778 10.20147
# 488125 1.044284 11.08972 13.75624 10.56768
# 675630 1.066374 11.62818 15.21913 10.52878
# 114652 1.008003 11.12094 14.70947 10.43206
# 926709 1.068915 11.54441 16.20800 10.73352
# 308841 1.081206 11.67320 15.51466 10.29161
# 376273 1.073495 11.42445 15.24748 10.87851
# 508267 1.101350 11.02624 12.90643 10.54169

# %%
length(NROY2)
# Out:
# [1] 31812

# %% [markdown]
# # Wave 3

# %%
40/ratio2
# Out:
# [1] 1257.387

# %%
set.seed(42)

designpoints2 <- data.frame()

while (nrow(designpoints2) <= 40) { 
        ### Emulator wave 1
        tmp <- as.data.frame(2*maximinLHS(ceil(40/ratio2), 4)-1)
        names(tmp) <- names(TestEm$fitting.elements$Design)
        imps_tmp <- ImplausibilityMOGP(NewData=tmp, Emulator=TestEm, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
        NROYtmp <- which(rowSums(imps_tmp <= cutoff_vec[1]) >= TestEm$mogp$n_emulators -valmax)
        ### Emulator wave 2
        imps_tmp2 <- ImplausibilityMOGP(NewData=tmp[NROYtmp,], Emulator=TestEm2, Discrepancy=tDisc, Obs=tObs2, ObsErr=tObsErr)
        NROYtmp2 <- which(rowSums(imps_tmp2 <= cutoff_vec[1]) >= TestEm2$mogp$n_emulators -valmax)
        #####
        selectionP <- tmp[NROYtmp,][NROYtmp2,]
        row.names(selectionP) <- NULL ## to avoid double index   
        designpoints2 <- rbind(designpoints2,selectionP)
        print(nrow(designpoints2))
        flush.console()
        } 

designpoints2 <- designpoints2[sample(nrow(designpoints2),40),]

designpoints_denorm2 <- rangeUnscale(designpoints2, my_bounds)
# Out:
# [1] 41

# %%
designpoints_denorm2
# Out:
#    h         F         c         b
# 27 1.6262770 12.681315  7.604530 13.732423
# 19 0.7118176  9.142802 13.966199  7.315658
# 12 1.7134744 13.631569 18.089063 11.628335
# 4  1.6101462  9.602840  7.352768 17.326021
# 24 0.8280480 11.046253 17.980656 12.762127
# 33 1.9893214  9.709105 11.650308 14.639706
# 32 0.4662600 10.574708  5.781078  4.898476
# 6  1.1787687  9.627556  5.551630 12.485608
# 7  1.5109925 12.232203  5.033509 12.929465
# 38 1.6927291 12.979854 13.473948 13.188067
# 35 1.1506346 11.207437 16.430456 13.825905
# 39 0.1193948  9.464543 12.759196  1.851959
# 5  1.6028637 10.804085 11.820510 13.242823
# 11 0.1666997 10.192983 13.686542  4.714061
# 13 1.0303736 10.909856 17.009639 10.005408
# 29 1.6607963 10.768949  2.012970 13.539678
# 40 1.4082904  9.787298  1.062291 10.028868
# 23 1.3542427  8.799700  3.582888 12.668112
# 41 0.8000529  9.495657 13.767716 10.710725
# 18 1.5363050 10.145587  4.863307 14.836475
# 36 1.9464561 14.594460 19.290408 14.454352
# 15 0.1635147 11.339574  6.789424  2.770643
# 25 1.1480854 10.162231  9.883959 12.723573
# 8  1.4843441 10.813458 13.655273 11.405236
# 22 0.3623249 10.606493  8.026597  7.376672
# 9  0.7247906  8.400660  2.535827 10.099450
# 21 1.8940395 12.007059 17.042955 13.596211
# 1  1.8254683 11.014308 12.344166 11.615221
# 31 0.2600865  8.504162  7.886027  1.304801
# 3  1.7721557 11.394044  9.511032 10.885971
# 10 1.5731695 11.639901  6.517198 10.582307
# 30 1.9171165 13.177284 10.854286 10.117100
# 2  0.5965499  7.450715  2.802430  6.442843
# 34 1.4116884  9.128081  6.534533 10.975716
# 20 1.3158949 13.260181 19.200226 12.554414
# 37 0.8775626 11.444822 18.922983  8.338930
# 26 1.1543821 11.156816 13.786142 10.214919
# 28 1.0179829  8.757772  4.185332 11.000367
# 17 0.1759394 10.889262 10.232942  4.961479
# 14 0.7161455 11.417464 16.485957  9.936326

# %%
write.csv(designpoints_denorm2,"/gpfswork/rech/omr/udu91zn/HighTune_R/Data/JAMES/exp_TuningL94_newPCA_PhysPrior_wave3.csv", row.names = FALSE)

# %%
inputs <- designpoints2

#Load outputs and select variables you want to keep
outputs <- read.csv('/gpfswork/rech/omr/udu91zn/HighTune_R/Data/JAMES/df_metrics_newPCA_PhysPrior_wave3.csv')
                         
set.seed(42)
N = nrow(inputs) #nb samples 
noise <- rnorm(N, 0, 0.5)
tData <- cbind(inputs, noise, outputs)
names(tData)[names(tData) == "noise"] <- "Noise"
                         
head(tData)
# Out:
#    h          F           c          b          Noise       pca_0
# 27  0.6262770  0.26813147 -0.3047863  0.3402551  0.68547922  7.1767460
# 19 -0.2881824 -0.08571981  0.3648631 -0.3351939 -0.28234909 -1.3308315
# 12  0.7134744  0.36315692  0.7988487  0.1187721  0.18156421  2.1956844
# 4   0.6101462 -0.03971599 -0.3312876  0.7185286  0.31643130  0.6218415
# 24 -0.1719520  0.10462528  0.7874375  0.2381186  0.20213416  1.9222872
# 33  0.9893214 -0.02908949  0.1210850  0.4357585 -0.05306226 -2.3732727
#    pca_1      pca_2     pca_3      pca_4
# 27 -3.5856759 -1.154674 -0.6929050 -1.28482568
# 19  1.4034950 -0.515228 -2.0616176 -0.53450659
# 12  0.5488190 -1.489286 -1.2034998 -1.21273504
# 4  -2.9848232 -2.042256 -0.4524787 -0.07763272
# 24 -4.0745323 -2.017125 -1.0082459  0.39628732
# 33  0.4898018 -1.111304 -0.5597041 -1.04867590

# %%
TestEm3 <- BuildNewEmulators(tData,
                            HowManyEmulators = length(outputs),
                            meanFun = "fitted",
                            #kernel = c("Matern52"),
                            additionalVariables = names(tData)[1:4])  #important to put this line

                            #Choices = lapply(1:length(outputs),
                            #                   function(k) choices.new),
# Out:
# [1] "Max reduction is 0.174604867042173 using b"
# [1] "Max reduction is 0.269935785369564 using F"
# [1] "Max reduction is 0.956819083032575 using c"
# [1] "Max reduction is 0.294566204070801 using h"
# [1] "Max reduction is 0.32443676985242 using b"
# [1] "Max reduction is 0.054867047080847 using Three Way Interactions with b"
# [1] "Max reduction is 0.0834883373652355 using b"
# [1] "Max reduction is 0.0012140263450553 using h"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = pca_0 ~ b + I(b^2) + I(b^3) + F + c + h + I(h^2) +
#     I(F * b) + I(c * b) + I(h * b) + I(c * F) + I(h * F) + I(h *
#     c) + I(b * F * b) + I(b * c * b) + I(b * h * b) + I(b * c *
#     F) + I(b * h * F) + I(b * h * c), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.73921 -0.32939 -0.05354  0.29618  1.83263
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)    1.7629     0.3629   4.857 9.55e-05 ***
# b              1.1349     1.8384   0.617  0.54399
# I(b^2)        -0.8762     6.5154  -0.134  0.89437
# I(b^3)       -13.4879     6.9077  -1.953  0.06501 .
# F             22.1438     3.2440   6.826 1.23e-06 ***
# c             -3.8910     0.7252  -5.365 2.98e-05 ***
# h             -3.0689     1.2109  -2.534  0.01973 *
# I(h^2)        -2.9777     2.9054  -1.025  0.31765
# I(F * b)      -7.2033    18.3914  -0.392  0.69945
# I(c * b)       9.3955     3.7706   2.492  0.02161 *
# I(h * b)       4.6729     8.5892   0.544  0.59243
# I(c * F)      -0.5567     2.8980  -0.192  0.84961
# I(h * F)      12.6372     9.4159   1.342  0.19460
# I(h * c)      -7.4627     2.1814  -3.421  0.00271 **
# I(b * F * b)  29.4930    41.4935   0.711  0.48542
# I(b * c * b) -21.4929    11.8628  -1.812  0.08506 .
# I(b * h * b)  10.4398     8.1059   1.288  0.21247
# I(b * c * F)  10.4457    11.7282   0.891  0.38371
# I(b * h * F) -46.9056    32.9165  -1.425  0.16958
# I(b * h * c)  16.4568     9.4153   1.748  0.09582 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.012 on 20 degrees of freedom
# Multiple R-squared:  0.9478,	Adjusted R-squared:  0.8982
# F-statistic: 19.11 on 19 and 20 DF,  p-value: 6.385e-09
#
# [1] "1 I(b * h * F)"
# [1] "2 I(b * c * b)"
# [1] "3 I(b * h * c)"
# [1] "4 I(b * c * F)"
# [1] "5 I(c * F)"
# [1] "6 I(b * h * b)"
# [1] "7 I(h * F)"
# [1] "8 I(b * F * b)"
# [1] "9 I(F * b)"
# [1] "10 I(h * b)"
# [1] "11 I(c * b)"
# [1] "12 I(h * c)"
# [1] "13 I(h^2)"
# [1] "14 h"
#
# Call:
# lm(formula = pca_0 ~ b + I(b^2) + I(b^3) + F + c, data = tData)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -2.587 -1.100 -0.214  1.056  2.733
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   1.3161     0.3894   3.380  0.00183 **
# b            -0.9460     1.4009  -0.675  0.50406
# I(b^2)        1.8802     1.9399   0.969  0.33926
# I(b^3)       -6.1538     3.1110  -1.978  0.05607 .
# F            17.3790     2.2048   7.882 3.53e-09 ***
# c            -4.0887     0.5731  -7.134 3.02e-08 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.671 on 34 degrees of freedom
# Multiple R-squared:  0.758,	Adjusted R-squared:  0.7224
# F-statistic:  21.3 on 5 and 34 DF,  p-value: 1.332e-09
#
# [1] "Max reduction is 0.273432606271474 using b"
# [1] "Max reduction is 0.485798021352672 using h"
# [1] "Max reduction is 0.612134194063993 using b"
# [1] "Max reduction is 0.360289045211489 using F"
# [1] "Max reduction is 0.315549426521761 using Three Way Interactions with b"
# [1] "Max reduction is 0.375920877041005 using b"
# [1] "Max reduction is 0.248334727082738 using c"
# [1] "Noise fitted, stopping algorithm"
#
# Call:
# lm(formula = pca_1 ~ b + I(b^2) + I(b^3) + h + F + c + I(h *
#     b) + I(F * b) + I(c * b) + I(F * h) + I(c * h) + I(c * F) +
#     I(b * h * b) + I(b * F * b) + I(b * c * b) + I(b * F * h) +
#     I(b * c * h) + I(b * c * F), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.13222 -0.21724  0.00639  0.23766  1.12808
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -1.1249     0.1964  -5.729 1.10e-05 ***
# b             -7.7761     1.0856  -7.163 4.62e-07 ***
# I(b^2)         9.9572     2.8100   3.543 0.001924 **
# I(b^3)       -21.1241     4.0534  -5.211 3.64e-05 ***
# h              5.2266     0.6423   8.137 6.26e-08 ***
# F             -6.0247     1.8577  -3.243 0.003893 **
# c              1.4865     0.4077   3.646 0.001509 **
# I(h * b)     -10.7901     2.3409  -4.609 0.000151 ***
# I(F * b)      -8.7954     7.3079  -1.204 0.242159
# I(c * b)      -0.5610     1.4888  -0.377 0.710067
# I(F * h)      -1.0257     3.5022  -0.293 0.772491
# I(c * h)       1.3658     1.0856   1.258 0.222136
# I(c * F)      -1.8274     1.7046  -1.072 0.295855
# I(b * h * b)  21.1691     4.7881   4.421 0.000237 ***
# I(b * F * b) -82.2109    22.3829  -3.673 0.001416 **
# I(b * c * b)  -2.1294     6.6483  -0.320 0.751908
# I(b * F * h)  47.9668    19.1142   2.509 0.020357 *
# I(b * c * h)  -2.4885     5.3136  -0.468 0.644373
# I(b * c * F)   3.2274     6.9946   0.461 0.649243
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.605 on 21 degrees of freedom
# Multiple R-squared:  0.9816,	Adjusted R-squared:  0.9659
# F-statistic: 62.38 on 18 and 21 DF,  p-value: 2.977e-14
#
# [1] "1 I(b * c * h)"
# [1] "2 I(b * c * F)"
# [1] "3 I(c * F)"
# [1] "4 I(b * c * b)"
# [1] "5 I(c * b)"
# [1] "6 I(b * F * h)"
# [1] "7 I(F * h)"
# [1] "8 I(c * h)"
# [1] "9 I(b * F * b)"
# [1] "10 I(F * b)"
# [1] "11 c"
# [1] "12 F"
# [1] "13 I(b^3)"
#
# Call:
# lm(formula = pca_1 ~ b + I(b^2) + h + I(h * b) + I(b * h * b),
#     data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.6294 -1.0267  0.2326  0.7359  6.5785
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -2.1091     0.4477  -4.711 4.06e-05 ***
# b            -10.2262     2.3083  -4.430 9.29e-05 ***
# I(b^2)        22.6552     4.5058   5.028 1.58e-05 ***
# h              6.7189     1.0071   6.671 1.17e-07 ***
# I(h * b)     -17.7405     3.8861  -4.565 6.25e-05 ***
# I(b * h * b)   3.0791     4.5324   0.679    0.502
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.92 on 34 degrees of freedom
# Multiple R-squared:  0.7007,	Adjusted R-squared:  0.6566
# F-statistic: 15.92 on 5 and 34 DF,  p-value: 4.433e-08
#
# [1] "Max reduction is 0.391863319595779 using b"
# [1] "Max reduction is 0.0721208536648168 using h"
# [1] "Max reduction is 0.0863073983147846 using c"
# [1] "Max reduction is 0.0597201792353759 using h"
# [1] "Max reduction is 0.0330023202739066 using F"
# [1] "Max reduction is 0.0265432614915369 using Three Way Interactions with h"
# [1] "Max reduction is 0.0218325476710812 using c"
# [1] "Max reduction is 0.00388732220794619 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = pca_2 ~ b + I(b^2) + h + I(h^2) + c + I(c^2) + F +
#     I(h * b) + I(c * b) + I(F * b) + I(c * h) + I(F * h) + I(F *
#     c) + I(h * h * b) + I(h * c * b) + I(h * F * b) + I(h * c *
#     h) + I(h * F * h) + I(h * F * c), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.44577 -0.09834 -0.04040  0.11154  0.63147
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -1.3181     0.1158 -11.381 3.44e-10 ***
# b             -3.1808     0.4024  -7.904 1.40e-07 ***
# I(b^2)         2.2113     1.7422   1.269  0.21892
# h              1.0218     0.3254   3.140  0.00515 **
# I(h^2)         0.2703     0.9035   0.299  0.76789
# c             -0.4195     0.2187  -1.919  0.06941 .
# I(c^2)         0.5911     0.3080   1.919  0.06935 .
# F              1.0116     0.9293   1.089  0.28930
# I(h * b)      -1.6424     2.4615  -0.667  0.51225
# I(c * b)      -0.9367     0.8318  -1.126  0.27349
# I(F * b)       7.3279     3.6077   2.031  0.05574 .
# I(c * h)       0.8754     0.6877   1.273  0.21764
# I(F * h)      -4.5005     3.2888  -1.368  0.18635
# I(F * c)      -3.7453     1.2780  -2.931  0.00827 **
# I(h * h * b)   0.7165     0.7114   1.007  0.32591
# I(h * c * b)  -3.1083     1.4364  -2.164  0.04275 *
# I(h * F * b)   4.2208     5.7427   0.735  0.47088
# I(h * c * h)   1.3494     1.1512   1.172  0.25492
# I(h * F * h)  -2.9114     4.3548  -0.669  0.51142
# I(h * F * c)   2.6519     1.7915   1.480  0.15438
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2691 on 20 degrees of freedom
# Multiple R-squared:  0.9601,	Adjusted R-squared:  0.9221
# F-statistic:  25.3 on 19 and 20 DF,  p-value: 4.833e-10
#
# [1] "1 I(h * F * h)"
# [1] "2 I(c^2)"
# [1] "3 I(h * c * b)"
# [1] "4 I(h * c * h)"
# [1] "5 I(h * F * c)"
# [1] "6 I(c * h)"
# [1] "7 I(h * F * b)"
# [1] "8 I(F * b)"
# [1] "9 I(c * b)"
# [1] "10 I(F * c)"
# [1] "11 I(F * h)"
# [1] "12 F"
# [1] "13 I(h * h * b)"
# [1] "14 I(h * b)"
#
# Call:
# lm(formula = pca_2 ~ b + I(b^2) + h + I(h^2) + c, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.91205 -0.23981 -0.03922  0.25054  0.68408
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.28612    0.09883 -13.014 9.23e-15 ***
# b           -2.39559    0.35136  -6.818 7.62e-08 ***
# I(b^2)       1.92072    0.43625   4.403 0.000101 ***
# h            0.87435    0.27317   3.201 0.002968 **
# I(h^2)      -0.53717    0.33281  -1.614 0.115757
# c           -0.42214    0.11426  -3.695 0.000770 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3917 on 34 degrees of freedom
# Multiple R-squared:  0.8562,	Adjusted R-squared:  0.835
# F-statistic: 40.48 on 5 and 34 DF,  p-value: 2.273e-13
#
# [1] "Max reduction is 0.762448597130814 using b"
# [1] "Max reduction is 0.166654961937181 using b"
# [1] "Max reduction is 0.0447312641895152 using c"
# [1] "Max reduction is 0.0252421394911579 using Three Way Interactions with b"
# [1] "Noise fitted, stopping algorithm"
#
# Call:
# lm(formula = pca_3 ~ b + I(b^2) + c + I(c * b) + I(b * c * b),
#     data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.69667 -0.20259  0.00681  0.20016  0.89418
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -1.38568    0.06917 -20.033  < 2e-16 ***
# b             2.25261    0.17309  13.014 9.22e-15 ***
# I(b^2)       -1.93609    0.31311  -6.183 4.98e-07 ***
# c            -0.06849    0.12515  -0.547   0.5878
# I(c * b)     -0.90798    0.34516  -2.631   0.0127 *
# I(b * c * b)  2.01887    0.79208   2.549   0.0155 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3336 on 34 degrees of freedom
# Multiple R-squared:  0.9454,	Adjusted R-squared:  0.9373
# F-statistic: 117.7 on 5 and 34 DF,  p-value: < 2.2e-16
#
# [1] "Max reduction is 0.0706657931723775 using h"
# [1] "Max reduction is 0.0765371109028967 using F"
# [1] "Max reduction is 0.130260345255995 using b"
# [1] "Max reduction is 0.130233033474313 using b"
# [1] "Max reduction is 0.27611644490593 using Three Way Interactions with b"
# [1] "Noise fitted, stopping algorithm"
#
# Call:
# lm(formula = pca_4 ~ h + F + b + I(b^2) + I(F * h) + I(b * h) +
#     I(b * F) + I(b * F * h) + I(b * b * h) + I(b * b * F), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.02151 -0.33056 -0.01013  0.32048  1.38614
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -0.4529     0.1837  -2.465 0.019861 *
# h             -1.1945     0.5712  -2.091 0.045387 *
# F              1.7863     1.3789   1.295 0.205398
# b              2.2675     1.0620   2.135 0.041327 *
# I(b^2)         2.7848     2.1627   1.288 0.208041
# I(F * h)      -4.6633     3.0035  -1.553 0.131361
# I(b * h)      -3.5902     1.9757  -1.817 0.079539 .
# I(b * F)      -1.9358     5.4648  -0.354 0.725727
# I(b * F * h)  54.6107    13.7581   3.969 0.000435 ***
# I(b * b * h)  -2.3170     1.8367  -1.261 0.217196
# I(b * b * F) -90.9851    17.5680  -5.179 1.54e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7282 on 29 degrees of freedom
# Multiple R-squared:  0.8022,	Adjusted R-squared:  0.734
# F-statistic: 11.76 on 10 and 29 DF,  p-value: 9.485e-08
#
# [1] "1 I(b * b * h)"
# [1] "2 I(b * F * h)"
# [1] "3 I(F * h)"
# [1] "4 I(b * h)"
# [1] "5 I(b^2)"
#
# Call:
# lm(formula = pca_4 ~ h + F + b + I(b * F) + I(b * b * F), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.31012 -0.32298  0.05828  0.32700  2.76790
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -0.5208     0.1674  -3.112  0.00375 **
# h             -1.7321     0.5105  -3.393  0.00177 **
# F              1.9072     1.4329   1.331  0.19205
# b              1.5189     0.7007   2.168  0.03728 *
# I(b * F)       6.8650     3.1521   2.178  0.03645 *
# I(b * b * F) -30.9377     6.4398  -4.804 3.08e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8817 on 34 degrees of freedom
# Multiple R-squared:   0.66,	Adjusted R-squared:   0.61
# F-statistic:  13.2 on 5 and 34 DF,  p-value: 3.55e-07

# %%
cands <- names(tData)[1:4]
tLOOs <- LOO.plot(Emulators = TestEm3, which.emulator = 1, ParamNames = cands, Obs = tObs2[1], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm3, which.emulator = 2, ParamNames = cands, Obs = tObs2[2], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm3, which.emulator = 3, ParamNames = cands, Obs = tObs2[3], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm3, which.emulator = 4, ParamNames = cands, Obs = tObs2[4], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm3, which.emulator = 5, ParamNames = cands, Obs = tObs2[5], ObsErr = 0.)#tLOOs <-
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
Timps3 <- matrix(rep(t(Timps2),1), ncol=ncol(Timps2), byrow=TRUE)
system.time(Timps3[NROY2,] <- ImplausibilityMOGP(NewData=Xp[NROY2,], Emulator=TestEm3, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr))
# Out:
#    user  system elapsed
#   1.553   5.043   1.618

# %%
ImpData_wave3 = cbind(Xp, Timps3)

# %%
valmax3 = 0 #how many outputs can be above the implausibility cut off?
ImpListM3 = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave3, nEms=TestEm3$mogp$n_emulators, whichMax=valmax3+1)
NROY3 <- which(rowSums(Timps3 <= cutoff_vec[1]) >= TestEm3$mogp$n_emulators -valmax3)
ratio3 <- length(NROY3)/dim(Xp)[1]
ratio3
# Out:
# [1] 0.00589

# %%
imp.layoutm11(ImpListM3,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",length(NROY3)/dim(Xp)[1],sep=""), side=1)
# Out:
# plot without title

# %%
length(NROY3)
# Out:
# [1] 5890

# %% [markdown]
# ## wave 4

# %%
40/ratio3
# Out:
# [1] 6791.171

# %% [markdown]
# switch to randomLHS

# %%
set.seed(42)

designpoints3 <- data.frame()

while (nrow(designpoints3) <= 40) { 
        ### Emulator wave 1
        tmp <- as.data.frame(2*randomLHS(ceil(40/ratio3), 4)-1)
        names(tmp) <- names(TestEm$fitting.elements$Design)
        imps_tmp <- ImplausibilityMOGP(NewData=tmp, Emulator=TestEm, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
        NROYtmp <- which(rowSums(imps_tmp <= cutoff_vec[1]) >= TestEm$mogp$n_emulators -valmax)
        ### Emulator wave 2
        imps_tmp2 <- ImplausibilityMOGP(NewData=tmp[NROYtmp,], Emulator=TestEm2, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
        NROYtmp2 <- which(rowSums(imps_tmp2 <= cutoff_vec[1]) >= TestEm2$mogp$n_emulators -valmax)
        ### Emulator wave 3
        imps_tmp3 <- ImplausibilityMOGP(NewData=tmp[NROYtmp,][NROYtmp2,], Emulator=TestEm3, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
        NROYtmp3 <- which(rowSums(imps_tmp3 <= cutoff_vec[1]) >= TestEm3$mogp$n_emulators -valmax)
        #####
        selectionP <- tmp[NROYtmp,][NROYtmp2,][NROYtmp3,]
        row.names(selectionP) <- NULL ## to avoid double index   
        designpoints3 <- rbind(designpoints3,selectionP)
        print(nrow(designpoints3))
        flush.console()
        } 

designpoints3 <- designpoints3[sample(nrow(designpoints3),40),]

designpoints_denorm3 <- rangeUnscale(designpoints3, my_bounds)
# Out:
# [1] 38
# [1] 74

# %%
write.csv(designpoints_denorm3,"/gpfswork/rech/omr/udu91zn/HighTune_R/Data/JAMES/exp_TuningL94_newPCA_PhysPrior_wave4.csv", row.names = FALSE)

# %%
designpoints3
# Out:
#    h            F            c           b
# 46 -0.088883705  0.017322376 -0.78135058  0.30272774
# 3   0.011886523  0.115362182 -0.21866132 -0.15552112
# 29 -0.205891733  0.278400769  0.88358393 -0.12685823
# 49 -0.315945830 -0.068230065 -0.90248064  0.07802248
# 66  0.370382555  0.235363071  0.51362517 -0.04196303
# 72  0.138066841  0.198386830  0.98064862  0.51175937
# 4   0.058863666  0.317184256  0.90568924 -0.01148172
# 36  0.019299174  0.190084645  0.96105700  0.60968899
# 13 -0.408141552 -0.146803268 -0.99150631 -0.08870328
# 28  0.152928211  0.083690755 -0.12076296  0.04663691
# 43  0.094408041 -0.262340894 -0.92561315  0.15870608
# 26  0.343451153  0.308371739  0.88412294  0.10284548
# 45 -0.111468153  0.145518373  0.91504424  0.05581483
# 5  -0.148699827  0.155077510  0.56612890 -0.23520396
# 48 -0.375502378 -0.092328985 -0.53636834 -0.04058814
# 21  0.093439026 -0.034023678 -0.21911581  0.07230646
# 1   0.128997998 -0.002724417 -0.35509779  0.04854112
# 6  -0.435957412 -0.063241531 -0.71534309 -0.04719730
# 32  0.129351602  0.168920720  0.81837138  0.05131897
# 41 -0.439096098  0.022846184  0.24344282 -0.29972385
# 42  0.172793672  0.247402452  0.98929274  0.58146076
# 23  0.015649040  0.299578734  0.65870791  0.01576838
# 34  0.048786407  0.196649727 -0.02512128 -0.14110164
# 18  0.179606228  0.058776637 -0.69511604 -0.07548407
# 7  -0.109209065 -0.051450792 -0.24154545  0.20309103
# 62 -0.674298253 -0.024997310  0.74112321 -0.31397010
# 68 -0.118269331 -0.123642165 -0.35209857  0.04100620
# 74 -0.406750375  0.010665012  0.66503355 -0.12836653
# 2   0.121897950 -0.082258396 -0.39612367  0.03286871
# 30 -0.454985904 -0.021145621  0.20658527 -0.21352738
# 50  0.519190158  0.220832538  0.64997163  0.07471710
# 59 -0.005249503 -0.231799416 -0.94770665  0.23412675
# 24  0.322209681  0.218112355  0.58875111  0.05724062
# 56 -0.431861029  0.026388059  0.62983844 -0.16405824
# 47 -0.235453028  0.040773531  0.51067929 -0.27726310
# 16  0.138653218  0.019724653 -0.64296865  0.10975896
# 44 -0.330256470  0.065780308  0.30052288 -0.20194143
# 10 -0.178235788 -0.050466885 -0.28199375  0.05501980
# 67 -0.411058447 -0.011222530  0.38685357 -0.23162499
# 57 -0.748669048  0.068020686  0.94958749 -0.25878369

# %%
inputs <- designpoints3

#Load outputs and select variables you want to keep
outputs <- read.csv('/gpfswork/rech/omr/udu91zn/HighTune_R/Data/JAMES/df_metrics_newPCA_PhysPrior_wave4.csv')
                         
set.seed(42)
N = nrow(inputs) #nb samples 
noise <- rnorm(N, 0, 0.5)
tData <- cbind(inputs, noise, outputs)
names(tData)[names(tData) == "noise"] <- "Noise"
                         
head(tData)
# Out:
#    h           F           c          b           Noise       pca_0
# 46 -0.08888370  0.01732238 -0.7813506  0.30272774  0.68547922 2.1897305
# 3   0.01188652  0.11536218 -0.2186613 -0.15552112 -0.28234909 6.1668736
# 29 -0.20589173  0.27840077  0.8835839 -0.12685823  0.18156421 5.5224137
# 49 -0.31594583 -0.06823006 -0.9024806  0.07802248  0.31643130 0.6182055
# 66  0.37038256  0.23536307  0.5136252 -0.04196303  0.20213416 1.2765685
# 72  0.13806684  0.19838683  0.9806486  0.51175937 -0.05306226 2.3433992
#    pca_1      pca_2     pca_3      pca_4
# 46 -4.1153665 -1.204344 -0.8044648 -0.1235898
# 3  -1.1960135 -1.002997 -2.2110588 -1.3146446
# 29 -2.9068709 -1.424775 -2.2226744 -0.3160798
# 49 -3.2150400 -1.256367 -0.8514099  0.5695557
# 66  0.8714935 -0.961259 -1.4427340 -1.2856235
# 72 -4.3853334 -2.127503 -0.6718112  0.3144345

# %%
TestEm4 <- BuildNewEmulators(tData,
                            HowManyEmulators = length(outputs),
                            meanFun = "fitted",
                            #kernel = c("Matern52"),
                            additionalVariables = names(tData)[1:4])  #important to put this line

                            #Choices = lapply(1:length(outputs),
                            #                   function(k) choices.new),
# Out:
# [1] "Max reduction is 0.347226633669319 using F"
# [1] "Max reduction is 0.37269041029522 using c"
# [1] "Max reduction is 0.183732274280872 using h"
# [1] "Max reduction is 0.170625282986707 using b"
# [1] "Max reduction is 0.108650026760069 using F"
# [1] "Max reduction is 0.148935136773679 using Three Way Interactions with F"
# [1] "Noise fitted, stopping algorithm"
#
# Call:
# lm(formula = pca_0 ~ F + I(F^2) + c + h + b + I(c * F) + I(h *
#     F) + I(b * F) + I(h * c) + I(b * c) + I(b * h) + I(F * c *
#     F) + I(F * h * F) + I(F * b * F) + I(F * h * c) + I(F * b *
#     c) + I(F * b * h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.21194 -0.42710 -0.00709  0.35665  0.84724
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)     1.8561     0.2774   6.691 1.00e-06 ***
# F              23.6470     4.6022   5.138 3.77e-05 ***
# I(F^2)         16.7183    21.8476   0.765 0.452269
# c              -4.8880     0.8252  -5.923 5.83e-06 ***
# h              -3.5535     1.5458  -2.299 0.031390 *
# b               0.6982     2.4266   0.288 0.776266
# I(c * F)       -3.9360     7.7125  -0.510 0.614894
# I(h * F)       16.1601    12.8883   1.254 0.223055
# I(b * F)      -45.2350    25.3745  -1.783 0.088442 .
# I(h * c)       -9.8550     2.5391  -3.881 0.000805 ***
# I(b * c)       17.9664     3.7724   4.763 9.38e-05 ***
# I(b * h)        0.8212     8.7803   0.094 0.926335
# I(F * c * F)   -2.3481    18.0691  -0.130 0.897786
# I(F * h * F) -287.1106    88.3746  -3.249 0.003683 **
# I(F * b * F)  259.6998   153.1837   1.695 0.104118
# I(F * h * c)  101.1998    30.3558   3.334 0.003011 **
# I(F * b * c)  -91.7287    36.1597  -2.537 0.018792 *
# I(F * b * h)    6.3979    53.0428   0.121 0.905089
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7169 on 22 degrees of freedom
# Multiple R-squared:  0.9309,	Adjusted R-squared:  0.8775
# F-statistic: 17.44 on 17 and 22 DF,  p-value: 5.181e-09
#
# [1] "1 I(F * b * h)"
# [1] "2 I(b * h)"
# [1] "3 I(F * h * F)"
# [1] "4 I(F * b * F)"
# [1] "5 I(F * b * c)"
# [1] "6 I(F * h * c)"
# [1] "7 I(h * c)"
# [1] "8 I(F * c * F)"
# [1] "9 I(b * c)"
# [1] "10 I(F^2)"
# [1] "11 I(b * F)"
# [1] "12 b"
#
# Call:
# lm(formula = pca_0 ~ F + c + h + I(c * F) + I(h * F), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.1042 -0.4880  0.1873  0.7257  2.4690
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   2.3152     0.3286   7.046 3.91e-08 ***
# F            18.7175     2.5713   7.279 1.98e-08 ***
# c            -2.3188     0.5324  -4.355 0.000116 ***
# h             0.1773     0.9392   0.189 0.851393
# I(c * F)     -5.7944     2.2915  -2.529 0.016257 *
# I(h * F)    -19.7559     6.2623  -3.155 0.003353 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.189 on 34 degrees of freedom
# Multiple R-squared:  0.7063,	Adjusted R-squared:  0.6631
# F-statistic: 16.35 on 5 and 34 DF,  p-value: 3.245e-08
#
# [1] "Max reduction is 0.115927635613864 using h"
# [1] "Max reduction is 0.605369807869282 using b"
# [1] "Max reduction is 0.125944580324734 using F"
# [1] "Max reduction is 0.173448211846385 using c"
# [1] "Max reduction is 0.194731024654799 using b"
# [1] "Max reduction is 0.0441920569374568 using F"
# [1] "Max reduction is 0.0179611914067951 using Three Way Interactions with F"
# [1] "Max reduction is 0.0289728871527189 using Three Way Interactions with b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = pca_1 ~ h + b + I(b^2) + F + I(F^2) + c + I(b *
#     h) + I(F * h) + I(c * h) + I(F * b) + I(c * b) + I(c * F) +
#     I(F * b * h) + I(F * F * h) + I(F * c * h) + I(F * F * b) +
#     I(F * c * b) + I(F * c * F) + I(b * b * h) + I(b * c * h) +
#     I(b * F * b) + I(b * c * b), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.27190 -0.05979  0.01915  0.07207  0.19637
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -1.49727    0.07054 -21.226 1.13e-13 ***
# h              5.79685    0.37203  15.582 1.69e-11 ***
# b             -9.41311    0.59509 -15.818 1.33e-11 ***
# I(b^2)        12.10817    2.26618   5.343 5.38e-05 ***
# F             -6.14530    1.11882  -5.493 3.96e-05 ***
# I(F^2)       -13.37978    5.08806  -2.630  0.01757 *
# c              1.08704    0.19853   5.475 4.10e-05 ***
# I(b * h)      -9.37485    2.47353  -3.790  0.00146 **
# I(F * h)       1.47609    3.36035   0.439  0.66600
# I(c * h)       2.27064    0.68101   3.334  0.00393 **
# I(F * b)      -0.26332    7.57454  -0.035  0.97267
# I(c * b)      -3.58153    1.16432  -3.076  0.00685 **
# I(c * F)       4.64827    1.71450   2.711  0.01483 *
# I(F * b * h) -19.60890   22.26662  -0.881  0.39079
# I(F * F * h)  20.14291   21.10105   0.955  0.35316
# I(F * c * h)  -4.32443    7.19893  -0.601  0.55596
# I(F * F * b)  31.24265   45.11107   0.693  0.49793
# I(F * c * b) -11.81694   12.41009  -0.952  0.35434
# I(F * c * F)  -3.05291    4.39928  -0.694  0.49708
# I(b * b * h)  21.66491    6.63280   3.266  0.00455 **
# I(b * c * h)   1.89590    2.88274   0.658  0.51955
# I(b * F * b) -31.57550   17.20359  -1.835  0.08400 .
# I(b * c * b)   5.94152    2.86234   2.076  0.05340 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1558 on 17 degrees of freedom
# Multiple R-squared:  0.9949,	Adjusted R-squared:  0.9883
# F-statistic: 150.4 on 22 and 17 DF,  p-value: 2.035e-15
#
# [1] "1 I(F * F * h)"
# [1] "2 I(F * c * b)"
# [1] "3 I(b * F * b)"
# [1] "4 I(b * c * h)"
# [1] "5 I(F * c * h)"
# [1] "6 I(F * F * b)"
# [1] "7 I(F * b * h)"
# [1] "8 I(b * c * b)"
# [1] "9 I(F * c * F)"
# [1] "10 I(b * b * h)"
# [1] "11 I(b^2)"
# [1] "12 I(c * b)"
# [1] "13 I(c * F)"
# [1] "14 I(F * b)"
# [1] "15 I(F^2)"
# [1] "16 I(b * h)"
# [1] "17 I(F * h)"
#
# Call:
# lm(formula = pca_1 ~ h + b + F + c + I(c * h), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.4968 -0.2608 -0.1450  0.1426  1.2825
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.28758    0.09471 -13.595 2.64e-15 ***
# h            5.59098    0.36308  15.399  < 2e-16 ***
# b           -6.95364    0.40051 -17.362  < 2e-16 ***
# F           -7.31272    1.00905  -7.247 2.18e-08 ***
# c            1.05063    0.21207   4.954 1.97e-05 ***
# I(c * h)     1.98574    0.44110   4.502 7.53e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4351 on 34 degrees of freedom
# Multiple R-squared:  0.9203,	Adjusted R-squared:  0.9085
# F-statistic: 78.49 on 5 and 34 DF,  p-value: < 2.2e-16
#
# [1] "Max reduction is 0.0641323436048643 using b"
# [1] "Max reduction is 0.0325091498517667 using c"
# [1] "Max reduction is 0.0263368515388406 using h"
# [1] "Max reduction is 0.0432311926564846 using b"
# [1] "Max reduction is 0.0063245411455273 using Three Way Interactions with b"
# [1] "Max reduction is 0.00174034252996708 using c"
# [1] "Max reduction is 0.00279288761696478 using c"
# [1] "Max reduction is 0.00463455643595806 using c"
# [1] "Max reduction is 0.0131274480753519 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = pca_2 ~ b + I(b^2) + c + I(c^2) + I(c^3) + I(c^4) +
#     I(c^5) + h + I(c * b) + I(h * b) + I(h * c) + I(b * c * b) +
#     I(b * h * b) + I(b * h * c), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.35130 -0.07222  0.00249  0.05828  0.31646
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -1.44581    0.08348 -17.320 1.95e-15 ***
# b            -2.49372    0.34468  -7.235 1.40e-07 ***
# I(b^2)        2.20990    1.38095   1.600   0.1221
# c             0.01267    0.29332   0.043   0.9659
# I(c^2)        0.50608    0.37811   1.338   0.1928
# I(c^3)       -1.96671    1.02835  -1.912   0.0673 .
# I(c^4)       -0.36031    0.38686  -0.931   0.3606
# I(c^5)        1.95316    0.83414   2.342   0.0275 *
# h             0.81535    0.15046   5.419 1.26e-05 ***
# I(c * b)     -1.49544    0.65384  -2.287   0.0309 *
# I(h * b)     -2.73668    1.30497  -2.097   0.0463 *
# I(h * c)      0.27415    0.24149   1.135   0.2670
# I(b * c * b)  2.27582    1.82381   1.248   0.2237
# I(b * h * b)  2.47360    3.10198   0.797   0.4327
# I(b * h * c)  0.65317    1.64475   0.397   0.6946
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1586 on 25 degrees of freedom
# Multiple R-squared:  0.8709,	Adjusted R-squared:  0.7986
# F-statistic: 12.05 on 14 and 25 DF,  p-value: 8.068e-08
#
# [1] "1 I(b * h * c)"
# [1] "2 I(h * c)"
# [1] "3 I(b * h * b)"
# [1] "4 I(b * c * b)"
# [1] "5 I(c * b)"
# [1] "6 I(h * b)"
# [1] "7 I(b^2)"
# [1] "8 I(c^5)"
# [1] "9 I(c^4)"
#
# Call:
# lm(formula = pca_2 ~ b + c + I(c^2) + I(c^3) + h, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.40790 -0.12259 -0.00153  0.08626  0.70618
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.34917    0.06666 -20.239  < 2e-16 ***
# b           -1.44869    0.27458  -5.276 7.53e-06 ***
# c           -0.27453    0.18177  -1.510  0.14020
# I(c^2)       0.11259    0.13819   0.815  0.42086
# I(c^3)       0.05171    0.24457   0.211  0.83381
# h            0.54548    0.15954   3.419  0.00165 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2273 on 34 degrees of freedom
# Multiple R-squared:  0.6393,	Adjusted R-squared:  0.5862
# F-statistic: 12.05 on 5 and 34 DF,  p-value: 9.31e-07
#
# [1] "Max reduction is 0.217414462549966 using b"
# [1] "Max reduction is 0.0253660342804455 using h"
# [1] "Max reduction is 0.0540073070236223 using h"
# [1] "Noise fitted, stopping algorithm"
#
# Call:
# lm(formula = pca_3 ~ b + h + I(h^2) + I(h * b), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.29542 -0.12129 -0.04887  0.04380  0.72868
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -1.7026     0.0484 -35.180  < 2e-16 ***
# b             2.5861     0.2056  12.578 1.52e-14 ***
# h            -0.4800     0.1701  -2.822  0.00782 **
# I(h^2)        2.3464     0.5243   4.475 7.74e-05 ***
# I(h * b)     -3.6732     1.1453  -3.207  0.00286 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2285 on 35 degrees of freedom
# Multiple R-squared:  0.8302,	Adjusted R-squared:  0.8108
# F-statistic: 42.77 on 4 and 35 DF,  p-value: 5.2e-13
#
# [1] "Max reduction is 0.0731270884065655 using h"
# [1] "Max reduction is 0.171187545903056 using b"
# [1] "Max reduction is 0.0405859760017189 using c"
# [1] "Noise fitted, stopping algorithm"
#
# Call:
# lm(formula = pca_4 ~ h + b + c + I(b * h) + I(c * h) + I(c *
#     b), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.73173 -0.15210 -0.01461  0.15034  1.44838
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.61193    0.07946  -7.701 7.22e-09 ***
# h           -2.17270    0.31037  -7.000 5.25e-08 ***
# b            2.35322    0.45517   5.170 1.12e-05 ***
# c            0.10308    0.12733   0.810  0.42400
# I(b * h)     2.44271    1.76082   1.387  0.17466
# I(c * h)     1.39097    0.42437   3.278  0.00247 **
# I(c * b)    -0.58099    0.58939  -0.986  0.33143
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.379 on 33 degrees of freedom
# Multiple R-squared:  0.7243,	Adjusted R-squared:  0.6741
# F-statistic: 14.45 on 6 and 33 DF,  p-value: 5.197e-08
#
# [1] "1 I(b * h)"
#
# Call:
# lm(formula = pca_4 ~ h + b + c + I(c * h) + I(c * b), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.73060 -0.11545 -0.01989  0.13631  1.51468
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.55774    0.07014  -7.952 2.90e-09 ***
# h           -2.37176    0.27893  -8.503 6.24e-10 ***
# b            2.25776    0.45601   4.951 1.99e-05 ***
# c            0.16559    0.12070   1.372  0.17909
# I(c * h)     1.20775    0.40874   2.955  0.00565 **
# I(c * b)    -0.41776    0.58532  -0.714  0.48027
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3841 on 34 degrees of freedom
# Multiple R-squared:  0.7082,	Adjusted R-squared:  0.6653
# F-statistic:  16.5 on 5 and 34 DF,  p-value: 2.916e-08

# %%
cands <- names(tData)[1:4]
tLOOs <- LOO.plot(Emulators = TestEm4, which.emulator = 1, ParamNames = cands, Obs = tObs2[1], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm4, which.emulator = 2, ParamNames = cands, Obs = tObs2[2], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm4, which.emulator = 3, ParamNames = cands, Obs = tObs2[3], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm4, which.emulator = 4, ParamNames = cands, Obs = tObs2[4], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm4, which.emulator = 5, ParamNames = cands, Obs = tObs2[5], ObsErr = 0.)#tLOOs <-
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
Timps4 <- matrix(rep(t(Timps3),1), ncol=ncol(Timps3), byrow=TRUE)
system.time(Timps4[NROY3,] <- ImplausibilityMOGP(NewData=Xp[NROY3,], Emulator=TestEm4, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr))
# Out:
#    user  system elapsed
#   0.870   4.121   1.549

# %%
ImpData_wave4 = cbind(Xp, Timps4)

# %%
valmax4 = 0 #how many outputs can be above the implausibility cut off?
ImpListM4 = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave4, nEms=TestEm4$mogp$n_emulators, whichMax=valmax4+1)
NROY4 <- which(rowSums(Timps4 <= cutoff_vec[1]) >= TestEm4$mogp$n_emulators -valmax4)
ratio4 <- length(NROY4)/dim(Xp)[1]
ratio4
# Out:
# [1] 0.000379

# %%
imp.layoutm11(ImpListM4,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",length(NROY4)/dim(Xp)[1],sep=""), side=1)
# Out:
# plot without title

# %%
length(NROY4)
# Out:
# [1] 379

# %% [markdown]
# ## wave 5

# %%
40/ratio4
# Out:
# [1] 105540.9

# %%
set.seed(42)

designpoints4 <- data.frame()

while (nrow(designpoints4) <= 40) {
        ### Emulator wave 1
        tmp <- as.data.frame(2*randomLHS(ceil(40/ratio4), 4)-1)
        names(tmp) <- names(TestEm$fitting.elements$Design)
        imps_tmp <- ImplausibilityMOGP(NewData=tmp, Emulator=TestEm, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
        NROYtmp <- which(rowSums(imps_tmp <= cutoff_vec[1]) >= TestEm$mogp$n_emulators -valmax)
        ### Emulator wave 2
        imps_tmp2 <- ImplausibilityMOGP(NewData=tmp[NROYtmp,], Emulator=TestEm2, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
        NROYtmp2 <- which(rowSums(imps_tmp2 <= cutoff_vec[1]) >= TestEm2$mogp$n_emulators -valmax)
        ### Emulator wave 3
        imps_tmp3 <- ImplausibilityMOGP(NewData=tmp[NROYtmp,][NROYtmp2,], Emulator=TestEm3, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
        NROYtmp3 <- which(rowSums(imps_tmp3 <= cutoff_vec[1]) >= TestEm3$mogp$n_emulators -valmax)
        ### Emulator wave 4
        imps_tmp4 <- ImplausibilityMOGP(NewData=tmp[NROYtmp,][NROYtmp2,][NROYtmp3,], Emulator=TestEm4, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
        NROYtmp4 <- which(rowSums(imps_tmp4 <= cutoff_vec[1]) >= TestEm4$mogp$n_emulators -valmax)
        #####
        selectionP <- tmp[NROYtmp,][NROYtmp2,][NROYtmp3,][NROYtmp4,]
        row.names(selectionP) <- NULL ## to avoid double index   
        designpoints4 <- rbind(designpoints4,selectionP)
        print(nrow(designpoints4))
        flush.console()
        } 

designpoints4 <- designpoints4[sample(nrow(designpoints4),40),]

designpoints_denorm4 <- rangeUnscale(designpoints4, my_bounds)
# Out:
# [1] 37
# [1] 80

# %%
write.csv(designpoints_denorm4,"/gpfswork/rech/omr/udu91zn/HighTune_R/Data/JAMES/exp_TuningL94_newPCA_PhysPrior_wave5.csv", row.names = FALSE)

# %%
inputs <- designpoints4

#Load outputs and select variables you want to keep
outputs <- read.csv('/gpfswork/rech/omr/udu91zn/HighTune_R/Data/JAMES/df_metrics_newPCA_PhysPrior_wave5.csv')
                         
set.seed(42)
N = nrow(inputs) #nb samples 
noise <- rnorm(N, 0, 0.5)
tData <- cbind(inputs, noise, outputs)
names(tData)[names(tData) == "noise"] <- "Noise"
                         
head(tData)
# Out:
#    h          F           c          b            Noise       pca_0
# 80 -0.1611008  0.08976304 0.76887577 -0.099225122  0.68547922 1.074241
# 78  0.3696636  0.36655593 0.99257480  0.066266201 -0.28234909 2.072487
# 77  0.1321319  0.07662560 0.03251055  0.005722887  0.18156421 4.011929
# 79 -0.5380369 -0.01215882 0.10616843 -0.380817699  0.31643130 3.611551
# 36 -0.0521931  0.13104705 0.73894888 -0.021508758  0.20213416 1.106219
# 58 -0.4279352 -0.06139914 0.09130374 -0.289891865 -0.05306226 2.557008
#    pca_1      pca_2     pca_3     pca_4
# 80 -1.1704916 -1.456350 -1.745516 -0.3727466
# 78 -0.3478966 -1.211737 -1.425163 -1.0163178
# 77 -1.5348509 -1.556514 -1.773345 -0.5314149
# 79 -2.0249775 -1.052862 -2.869813 -0.4258052
# 36 -1.2736884 -1.282860 -1.557899 -0.4881075
# 58 -1.5928766 -1.443207 -2.448891 -0.2564091

# %%
TestEm5 <- BuildNewEmulators(tData,
                            HowManyEmulators = length(outputs),
                            meanFun = "fitted",
                            #kernel = c("Matern52"),
                            additionalVariables = names(tData)[1:4])  #important to put this line

                            #Choices = lapply(1:length(outputs),
                            #                   function(k) choices.new),
# Out:
# [1] "Max reduction is 0.059708140987824 using h"
# [1] "Max reduction is 0.246398205629015 using h"
# [1] "Max reduction is 0.0411454697062676 using c"
# [1] "Max reduction is 0.267040421577741 using F"
# [1] "Max reduction is 0.00896591566638061 using h"
# [1] "Max reduction is 0.00774352948226598 using Three Way Interactions with h"
# [1] "Noise fitted, stopping algorithm"
#
# Call:
# lm(formula = pca_0 ~ h + I(h^2) + I(h^3) + c + F + I(c * h) +
#     I(F * h) + I(F * c) + I(h * c * h) + I(h * F * h) + I(h *
#     F * c), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.19838 -0.27994  0.08303  0.38445  1.35690
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)    2.5096     0.3272   7.670 2.35e-08 ***
# h             -2.6641     1.9337  -1.378  0.17920
# I(h^2)       -19.9868    13.4187  -1.489  0.14754
# I(h^3)       -36.7832    23.1171  -1.591  0.12280
# c             -4.0024     1.2131  -3.299  0.00265 **
# F             18.3872     5.8104   3.165  0.00372 **
# I(c * h)     -12.1117     5.4544  -2.221  0.03465 *
# I(F * h)      42.6900    30.5322   1.398  0.17303
# I(F * c)      -7.3283     4.7840  -1.532  0.13679
# I(h * c * h)  -8.0151    21.0162  -0.381  0.70580
# I(h * F * h)  56.9643    56.4241   1.010  0.32135
# I(h * F * c)  14.4499    33.2779   0.434  0.66746
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.857 on 28 degrees of freedom
# Multiple R-squared:  0.7618,	Adjusted R-squared:  0.6683
# F-statistic: 8.143 on 11 and 28 DF,  p-value: 3.712e-06
#
# [1] "1 I(h^3)"
# [1] "2 I(h * F * h)"
# [1] "3 I(h * c * h)"
# [1] "4 I(h * F * c)"
# [1] "5 I(F * c)"
# [1] "6 I(F * h)"
#
# Call:
# lm(formula = pca_0 ~ h + I(h^2) + c + F + I(c * h), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.7115 -0.2810  0.1782  0.5084  1.4338
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   1.8960     0.2456   7.719 5.61e-09 ***
# h            -0.4262     1.5471  -0.275  0.78462
# I(h^2)        7.2310     3.1846   2.271  0.02962 *
# c            -4.4550     0.9492  -4.693 4.28e-05 ***
# F            17.4119     4.0594   4.289  0.00014 ***
# I(c * h)     -4.3727     2.0043  -2.182  0.03614 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9323 on 34 degrees of freedom
# Multiple R-squared:  0.6577,	Adjusted R-squared:  0.6074
# F-statistic: 13.07 on 5 and 34 DF,  p-value: 3.961e-07
#
# [1] "Max reduction is 0.0563836071686389 using F"
# [1] "Noise fitted, stopping algorithm"
#
# Call:
# lm(formula = pca_1 ~ F, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.69626 -0.25485 -0.09136  0.19881  1.08387
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.50143    0.07926 -18.943  < 2e-16 ***
# F            1.63103    0.44924   3.631  0.00083 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3873 on 38 degrees of freedom
# Multiple R-squared:  0.2575,	Adjusted R-squared:  0.238
# F-statistic: 13.18 on 1 and 38 DF,  p-value: 0.0008304
#
# [1] "Max reduction is 0.014327147304857 using b"
# [1] "Noise fitted, stopping algorithm"
#
# Call:
# lm(formula = pca_2 ~ b, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.45593 -0.15713 -0.05303  0.10220  0.77229
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.37081    0.04594 -29.839   <2e-16 ***
# b           -0.83654    0.36205  -2.311   0.0264 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2645 on 38 degrees of freedom
# Multiple R-squared:  0.1232,	Adjusted R-squared:  0.1001
# F-statistic: 5.339 on 1 and 38 DF,  p-value: 0.02638
#
# [1] "Max reduction is 0.191690605492841 using b"
# [1] "Max reduction is 0.0237175948061286 using h"
# [1] "Max reduction is 0.0050061250853892 using c"
# [1] "Max reduction is 0.00218178690829629 using F"
# [1] "Max reduction is 0.00781464045480668 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = pca_3 ~ b + h + I(h^2) + c + F + I(h * b) + I(c *
#     b) + I(F * b) + I(c * h) + I(F * h) + I(F * c), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.238167 -0.069589 -0.002214  0.035301  0.292572
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -1.6998     0.0461 -36.876   <2e-16 ***
# b             0.9253     1.1050   0.837   0.4095
# h             0.7742     0.6315   1.226   0.2304
# I(h^2)        6.3814     2.9757   2.145   0.0408 *
# c             0.1936     0.1695   1.142   0.2631
# F            -0.5510     0.9564  -0.576   0.5692
# I(h * b)    -10.8625     4.1775  -2.600   0.0147 *
# I(c * b)     -4.0168     3.3634  -1.194   0.2424
# I(F * b)     17.7254    10.6454   1.665   0.1070
# I(c * h)      2.7798     1.6643   1.670   0.1060
# I(F * h)    -14.3916     5.5098  -2.612   0.0143 *
# I(F * c)      0.4656     0.8841   0.527   0.6026
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1297 on 28 degrees of freedom
# Multiple R-squared:  0.9068,	Adjusted R-squared:  0.8702
# F-statistic: 24.78 on 11 and 28 DF,  p-value: 1.498e-11
#
# [1] "1 I(c * b)"
# [1] "2 I(F * b)"
# [1] "3 I(c * h)"
# [1] "4 I(F * h)"
# [1] "5 I(F * c)"
# [1] "6 I(h * b)"
#
# Call:
# lm(formula = pca_3 ~ b + h + I(h^2) + c + F, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.25435 -0.08631 -0.00679  0.05340  0.34420
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.64709    0.03457 -47.643   <2e-16 ***
# b            1.48165    0.93882   1.578   0.1238
# h            0.51648    0.53653   0.963   0.3425
# I(h^2)      -1.34149    0.51095  -2.625   0.0129 *
# c            0.28851    0.14977   1.926   0.0625 .
# F           -0.75339    0.68081  -1.107   0.2762
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.135 on 34 degrees of freedom
# Multiple R-squared:  0.8776,	Adjusted R-squared:  0.8596
# F-statistic: 48.74 on 5 and 34 DF,  p-value: 1.524e-14
#
# [1] "Max reduction is 0.0544706753885918 using h"
# [1] "Max reduction is 0.0214564962853126 using b"
# [1] "Max reduction is 0.000987155195272899 using h"
# [1] "Max reduction is 0.00141336945103016 using b"
# [1] "Max reduction is 0.000219287142021074 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = pca_4 ~ h + I(h^2) + I(h^3) + b + I(b^2) + I(b *
#     h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.53410 -0.07104  0.02342  0.10348  0.28983
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.48275    0.04434 -10.887 1.85e-12 ***
# h           -2.64806    0.63791  -4.151 0.000219 ***
# I(h^2)       1.09587    3.09984   0.354 0.725944
# I(h^3)       4.40856    4.23817   1.040 0.305807
# b            4.04753    1.29833   3.117 0.003767 **
# I(b^2)      14.44791   11.20714   1.289 0.206303
# I(b * h)    -7.63019   11.74977  -0.649 0.520581
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1819 on 33 degrees of freedom
# Multiple R-squared:  0.5873,	Adjusted R-squared:  0.5122
# F-statistic: 7.825 on 6 and 33 DF,  p-value: 2.757e-05
#
# [1] "1 I(h^3)"
#
# Call:
# lm(formula = pca_4 ~ h + I(h^2) + b + I(b^2) + I(b * h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.51982 -0.06573  0.02630  0.11973  0.27531
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.47389    0.04357 -10.877  1.3e-12 ***
# h            -2.61565    0.63791  -4.100 0.000243 ***
# I(h^2)        3.51275    2.05443   1.710 0.096408 .
# b             4.03098    1.29980   3.101 0.003860 **
# I(b^2)       13.93505   11.20979   1.243 0.222330
# I(b * h)    -13.82980   10.13819  -1.364 0.181490
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1821 on 34 degrees of freedom
# Multiple R-squared:  0.5737,	Adjusted R-squared:  0.511
# F-statistic: 9.152 on 5 and 34 DF,  p-value: 1.373e-05

# %%
cands <- names(tData)[1:4]
tLOOs <- LOO.plot(Emulators = TestEm5, which.emulator = 1, ParamNames = cands, Obs = tObs2[1], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm5, which.emulator = 2, ParamNames = cands, Obs = tObs2[2], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm5, which.emulator = 3, ParamNames = cands, Obs = tObs2[3], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm5, which.emulator = 4, ParamNames = cands, Obs = tObs2[4], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm5, which.emulator = 5, ParamNames = cands, Obs = tObs2[5], ObsErr = 0.)#tLOOs <-
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
Timps5 <- matrix(rep(t(Timps4),1), ncol=ncol(Timps4), byrow=TRUE)
system.time(Timps5[NROY4,] <- ImplausibilityMOGP(NewData=Xp[NROY4,], Emulator=TestEm5, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr))
# Out:
#    user  system elapsed
#   0.916   4.256   1.589

# %%
ImpData_wave5 = cbind(Xp, Timps5)

# %%
valmax5 = 0 #how many outputs can be above the implausibility cut off?
ImpListM5 = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave5, nEms=TestEm5$mogp$n_emulators, whichMax=valmax4+1)
NROY5 <- which(rowSums(Timps5 <= cutoff_vec[1]) >= TestEm5$mogp$n_emulators -valmax5)
ratio5 <- length(NROY5)/dim(Xp)[1]
ratio5
# Out:
# [1] 0.000183

# %%
imp.layoutm11(ImpListM5,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",length(NROY5)/dim(Xp)[1],sep=""), side=1)
# Out:
# plot without title

# %%
length(NROY5)
# Out:
# [1] 183

# %% [markdown]
# ## wave 6

# %%
40/ratio5
# Out:
# [1] 218579.2

# %%
set.seed(42)

designpoints5 <- data.frame()

############ SWITCH TO RANDOM LHS because it takes so much time !!!!!! ####################

while (nrow(designpoints5) < 40) {
        ### Emulator wave 1
        tmp <- as.data.frame(2*randomLHS(ceil(40/ratio5), 4)-1)
        names(tmp) <- names(TestEm$fitting.elements$Design)
        imps_tmp <- ImplausibilityMOGP(NewData=tmp, Emulator=TestEm, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
        NROYtmp <- which(rowSums(imps_tmp <= cutoff_vec[1]) >= TestEm$mogp$n_emulators -valmax)
        ### Emulator wave 2
        imps_tmp2 <- ImplausibilityMOGP(NewData=tmp[NROYtmp,], Emulator=TestEm2, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
        NROYtmp2 <- which(rowSums(imps_tmp2 <= cutoff_vec[1]) >= TestEm2$mogp$n_emulators -valmax)
        ### Emulator wave 3
        imps_tmp3 <- ImplausibilityMOGP(NewData=tmp[NROYtmp,][NROYtmp2,], Emulator=TestEm3, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
        NROYtmp3 <- which(rowSums(imps_tmp3 <= cutoff_vec[1]) >= TestEm3$mogp$n_emulators -valmax)
        ### Emulator wave 4
        imps_tmp4 <- ImplausibilityMOGP(NewData=tmp[NROYtmp,][NROYtmp2,][NROYtmp3,], Emulator=TestEm4, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
        NROYtmp4 <- which(rowSums(imps_tmp4 <= cutoff_vec[1]) >= TestEm4$mogp$n_emulators -valmax)
        ### Emulator wave 5
        imps_tmp5 <- ImplausibilityMOGP(NewData=tmp[NROYtmp,][NROYtmp2,][NROYtmp3,][NROYtmp4,], Emulator=TestEm5, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
        NROYtmp5 <- which(rowSums(imps_tmp5 <= cutoff_vec[1]) >= TestEm5$mogp$n_emulators -valmax)
        #####
        selectionP <- tmp[NROYtmp,][NROYtmp2,][NROYtmp3,][NROYtmp4,][NROYtmp5,]
        row.names(selectionP) <- NULL ## to avoid double index   
        designpoints5 <- rbind(designpoints5,selectionP)
        print(nrow(designpoints5))
        flush.console()
        } 

designpoints5 <- designpoints5[sample(nrow(designpoints5),40),]

designpoints_denorm5 <- rangeUnscale(designpoints5, my_bounds)
# Out:
# [1] 41

# %%
write.csv(designpoints_denorm5,"/gpfswork/rech/omr/udu91zn/HighTune_R/Data/JAMES/exp_TuningL94_newPCA_PhysPrior_wave6.csv", row.names = FALSE)

# %%
inputs <- designpoints5

#Load outputs and select variables you want to keep
outputs <- read.csv('/gpfswork/rech/omr/udu91zn/HighTune_R/Data/JAMES/df_metrics_newPCA_PhysPrior_wave6.csv')
                         
set.seed(42)
N = nrow(inputs) #nb samples 
noise <- rnorm(N, 0, 0.5)
tData <- cbind(inputs, noise, outputs)
names(tData)[names(tData) == "noise"] <- "Noise"
                         
head(tData)
# Out:
#    h           F            c           b            Noise       pca_0
# 3  -0.12340303 -0.135658472 -0.38813000 -0.087881309  0.68547922 1.253587
# 1   0.07007900  0.153010031  0.68676617  0.004170987 -0.28234909 2.912566
# 34 -0.28000122 -0.007186529  0.18683788 -0.144946691  0.18156421 1.818558
# 29  0.15569196  0.232527227  0.83865183  0.030236544  0.31643130 2.674127
# 12 -0.08626144  0.013670652  0.02476969 -0.065513491  0.20213416 3.027189
# 39  0.22173394  0.325991019  0.94283488  0.015134534 -0.05306226 3.822162
#    pca_1      pca_2     pca_3     pca_4
# 3  -0.9290304 -1.283630 -1.875317 -0.5041901
# 1  -1.4103367 -1.697310 -1.821587 -0.2578540
# 34 -1.7992808 -1.338281 -1.949876 -0.2913405
# 29 -1.1418400 -1.518828 -1.636623 -0.4921809
# 12 -1.7288572 -1.555684 -1.968067 -0.4077188
# 39 -1.0032599 -1.602630 -1.774543 -0.6480055

# %%
TestEm6 <- BuildNewEmulators(tData,
                            HowManyEmulators = length(outputs),
                            meanFun = "fitted",
                            #kernel = c("Matern52"),
                            additionalVariables = names(tData)[1:4])  #important to put this line

                            #Choices = lapply(1:length(outputs),
                            #                   function(k) choices.new),
# Out:
# [1] "Max reduction is 0.109700676579271 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = pca_0 ~ h, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.72933 -0.68819  0.08652  0.67095  1.45728
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   2.4829     0.1361  18.239  < 2e-16 ***
# h             3.0784     0.9033   3.408  0.00156 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8577 on 38 degrees of freedom
# Multiple R-squared:  0.2341,	Adjusted R-squared:  0.2139
# F-statistic: 11.61 on 1 and 38 DF,  p-value: 0.001561
#
# [1] "Max reduction is 0.0281773349337393 using F"
# [1] "Max reduction is 0.0242460231621635 using F"
# [1] "Max reduction is 0.0152808739799115 using b"
# [1] "Max reduction is 0.103202503366322 using h"
# [1] "Max reduction is 0.08521864374879 using c"
# [1] "Max reduction is 0.0262328975795403 using Three Way Interactions with F"
# [1] "Max reduction is 0.0212017502177143 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = pca_1 ~ F + I(F^2) + b + I(b^2) + h + c + I(b *
#     F) + I(h * F) + I(c * F) + I(h * b) + I(c * b) + I(c * h) +
#     I(F * b * F) + I(F * h * F) + I(F * c * F) + I(F * h * b) +
#     I(F * c * b) + I(F * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.262778 -0.046775  0.002816  0.038342  0.180425
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)    -1.62890    0.04798 -33.947  < 2e-16 ***
# F              -7.46727    1.60069  -4.665 0.000133 ***
# I(F^2)         -2.43177   19.43219  -0.125 0.901602
# b             -11.82884    1.62383  -7.285 3.57e-07 ***
# I(b^2)        -58.61182   19.39921  -3.021 0.006497 **
# h               8.03302    0.86965   9.237 7.63e-09 ***
# c               1.23477    0.39744   3.107 0.005338 **
# I(b * F)       97.19544   40.05092   2.427 0.024318 *
# I(h * F)      -48.70245   18.74237  -2.599 0.016770 *
# I(c * F)        2.61333    3.86548   0.676 0.506375
# I(h * b)       26.98390   13.25473   2.036 0.054582 .
# I(c * b)      -33.74054    9.58401  -3.521 0.002032 **
# I(c * h)       14.00533    5.13770   2.726 0.012658 *
# I(F * b * F) -892.48359  222.61409  -4.009 0.000636 ***
# I(F * h * F)  114.62795   64.18717   1.786 0.088575 .
# I(F * c * F)  -10.47727    9.56744  -1.095 0.285876
# I(F * h * b)   63.45797   64.84557   0.979 0.338917
# I(F * c * b)  192.10180   64.25786   2.990 0.006987 **
# I(F * c * h)  -13.43590   28.76510  -0.467 0.645245
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1245 on 21 degrees of freedom
# Multiple R-squared:  0.9544,	Adjusted R-squared:  0.9154
# F-statistic: 24.44 on 18 and 21 DF,  p-value: 3.39e-10
#
# [1] "1 I(F * c * h)"
# [1] "2 I(F * h * F)"
# [1] "3 I(F * c * F)"
# [1] "4 I(c * F)"
# [1] "5 I(c * h)"
# [1] "6 I(h * F)"
# [1] "7 I(F * b * F)"
# [1] "8 I(F * c * b)"
# [1] "9 I(c * b)"
# [1] "10 I(F * h * b)"
# [1] "11 I(h * b)"
# [1] "12 I(b^2)"
# [1] "13 c"
#
# Call:
# lm(formula = pca_1 ~ F + I(F^2) + b + h + I(b * F), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.43721 -0.17660 -0.06672  0.13676  0.60989
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -1.62253    0.05294 -30.650  < 2e-16 ***
# F            -2.69783    0.64829  -4.161 0.000203 ***
# I(F^2)        5.87726    1.98109   2.967 0.005476 **
# b            -8.77669    1.37380  -6.389 2.71e-07 ***
# h             4.97186    0.80602   6.168 5.21e-07 ***
# I(b * F)    -14.20479    4.67909  -3.036 0.004580 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2512 on 34 degrees of freedom
# Multiple R-squared:  0.6999,	Adjusted R-squared:  0.6557
# F-statistic: 15.86 on 5 and 34 DF,  p-value: 4.629e-08
#
# [1] "Max reduction is 0.0244244786887312 using b"
# [1] "Max reduction is 0.0260871764934014 using F"
# [1] "Max reduction is 0.0585366277864837 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = pca_2 ~ b + F + h + I(F * b) + I(h * b) + I(h *
#     F), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.24755 -0.09307 -0.02731  0.10348  0.29696
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -1.55650    0.03039 -51.219  < 2e-16 ***
# b            -3.56022    0.90624  -3.929 0.000412 ***
# F            -1.46083    0.33247  -4.394 0.000109 ***
# h             1.47286    0.47459   3.103 0.003908 **
# I(F * b)    -24.95630    3.97983  -6.271 4.36e-07 ***
# I(h * b)      0.29859    2.40925   0.124 0.902119
# I(h * F)      7.29164    1.82791   3.989 0.000347 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.142 on 33 degrees of freedom
# Multiple R-squared:  0.7293,	Adjusted R-squared:  0.6801
# F-statistic: 14.82 on 6 and 33 DF,  p-value: 3.875e-08
#
# [1] "1 I(h * b)"
#
# Call:
# lm(formula = pca_2 ~ b + F + h + I(F * b) + I(h * F), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.24611 -0.09331 -0.02658  0.10290  0.29462
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -1.55549    0.02885 -53.923  < 2e-16 ***
# b            -3.61455    0.78157  -4.625 5.24e-05 ***
# F            -1.46575    0.32527  -4.506 7.43e-05 ***
# h             1.47233    0.46765   3.148 0.003410 **
# I(F * b)    -25.00866    3.89962  -6.413 2.52e-07 ***
# I(h * F)      7.31031    1.79512   4.072 0.000263 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1399 on 34 degrees of freedom
# Multiple R-squared:  0.7292,	Adjusted R-squared:  0.6894
# F-statistic: 18.31 on 5 and 34 DF,  p-value: 8.517e-09
#
# [1] "Max reduction is 0.0504230835961546 using b"
# [1] "Max reduction is 0.0142828890241176 using F"
# [1] "Max reduction is 0.00578487374038462 using F"
# [1] "Max reduction is 0.0055003557301628 using c"
# [1] "Max reduction is 0.00417496286106625 using Three Way Interactions with F"
# [1] "Max reduction is 0.000682091818087094 using F"
# [1] "Max reduction is 0.00144948179031837 using h"
# [1] "Max reduction is 0.00519518985293183 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = pca_3 ~ b + I(b^2) + F + I(F^2) + I(F^3) + c + h +
#     I(F * b) + I(c * b) + I(h * b) + I(c * F) + I(h * F) + I(h *
#     c) + I(F * F * b) + I(F * c * b) + I(F * h * b) + I(F * c *
#     F) + I(F * h * F) + I(F * h * c), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.161558 -0.036119  0.003658  0.028250  0.098089
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)    -1.71842    0.03123 -55.029   <2e-16 ***
# b               0.88464    1.12292   0.788   0.4400
# I(b^2)        -30.44916   15.55979  -1.957   0.0645 .
# F              -1.46651    1.04628  -1.402   0.1764
# I(F^2)         -3.28419   12.48716  -0.263   0.7952
# I(F^3)         19.22585   60.54471   0.318   0.7541
# c               0.28624    0.28069   1.020   0.3200
# h               0.99751    0.58528   1.704   0.1038
# I(F * b)       23.82399   28.86288   0.825   0.4189
# I(c * b)       -9.67457    7.44958  -1.299   0.2088
# I(h * b)       16.73201    9.90224   1.690   0.1066
# I(c * F)        0.77098    2.60156   0.296   0.7700
# I(h * F)      -11.67303   15.49791  -0.753   0.4601
# I(h * c)        3.37176    4.01811   0.839   0.4113
# I(F * F * b) -306.26639  242.81984  -1.261   0.2217
# I(F * c * b)   58.24345   65.07316   0.895   0.3814
# I(F * h * b)   20.08461   41.61192   0.483   0.6346
# I(F * c * F)   -8.22072   20.63267  -0.398   0.6945
# I(F * h * F)   10.32102   99.20560   0.104   0.9182
# I(F * h * c)    3.98891   29.52830   0.135   0.8939
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07963 on 20 degrees of freedom
# Multiple R-squared:  0.8836,	Adjusted R-squared:  0.773
# F-statistic: 7.989 on 19 and 20 DF,  p-value: 1.137e-05
#
# [1] "1 I(F * h * c)"
# [1] "2 I(F * h * b)"
# [1] "3 I(F * h * F)"
# [1] "4 I(h * F)"
# [1] "5 I(h * c)"
# [1] "6 I(h * b)"
# [1] "7 I(F * c * F)"
# [1] "8 h"
# [1] "9 I(F^3)"
# [1] "10 I(F * c * b)"
# [1] "11 I(c * b)"
# [1] "12 I(b^2)"
# [1] "13 I(F^2)"
# [1] "14 I(c * F)"
#
# Call:
# lm(formula = pca_3 ~ b + F + c + I(F * b) + I(F * F * b), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.12822 -0.06383 -0.02005  0.06524  0.27385
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -1.708925   0.019623 -87.086  < 2e-16 ***
# b              2.183655   0.323763   6.745 9.45e-08 ***
# F              0.011549   0.371210   0.031   0.9754
# c              0.008563   0.113128   0.076   0.9401
# I(F * b)       0.910939   3.301253   0.276   0.7843
# I(F * F * b) -44.814701  17.548552  -2.554   0.0153 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09617 on 34 degrees of freedom
# Multiple R-squared:  0.7113,	Adjusted R-squared:  0.6689
# F-statistic: 16.76 on 5 and 34 DF,  p-value: 2.441e-08
#
# [1] "Max reduction is 0.0226307485479086 using F"
# [1] "Max reduction is 0.0428757130577486 using c"
# [1] "Max reduction is 0.0270893403951762 using b"
# [1] "Max reduction is 0.017037694106627 using h"
# [1] "Max reduction is 0.0075415278267804 using F"
# [1] "Max reduction is 0.00909689325350543 using Three Way Interactions with F"
# [1] "Max reduction is 0.0180671074542209 using b"
# [1] "Max reduction is 0.000267499310258171 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = pca_4 ~ F + I(F^2) + c + b + I(b^2) + I(b^3) + h +
#     I(c * F) + I(b * F) + I(h * F) + I(b * c) + I(h * c) + I(h *
#     b) + I(F * c * F) + I(F * b * F) + I(F * h * F) + I(F * b *
#     c) + I(F * h * c) + I(F * h * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.133883 -0.032810  0.001907  0.026041  0.197347
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)    -0.42681    0.03732 -11.438 3.16e-10 ***
# F              -1.42479    1.19062  -1.197  0.24542
# I(F^2)          9.68290   14.89290   0.650  0.52298
# c               0.68884    0.29557   2.331  0.03036 *
# b               3.59667    1.20783   2.978  0.00744 **
# I(b^2)         58.21953   18.10634   3.215  0.00434 **
# I(b^3)         34.39089   32.47070   1.059  0.30216
# h              -2.28028    0.64645  -3.527  0.00212 **
# I(c * F)       -2.81004    2.94539  -0.954  0.35145
# I(b * F)      -51.72256   29.71656  -1.741  0.09713 .
# I(h * F)       29.03178   14.31978   2.027  0.05616 .
# I(b * c)       18.24472    7.14197   2.555  0.01889 *
# I(h * c)       -8.05406    3.93683  -2.046  0.05415 .
# I(h * b)      -29.80486   10.77955  -2.765  0.01195 *
# I(F * c * F)    1.09625    7.17361   0.153  0.88007
# I(F * b * F)  523.98796  167.42328   3.130  0.00528 **
# I(F * h * F)  -74.62380   48.26752  -1.546  0.13777
# I(F * b * c) -108.18586   47.72585  -2.267  0.03464 *
# I(F * h * c)   13.07397   21.74162   0.601  0.55437
# I(F * h * b)  -11.65991   48.40119  -0.241  0.81208
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0924 on 20 degrees of freedom
# Multiple R-squared:  0.9221,	Adjusted R-squared:  0.848
# F-statistic: 12.45 on 19 and 20 DF,  p-value: 2.842e-07
#
# [1] "1 I(F * h * b)"
# [1] "2 I(F * h * c)"
# [1] "3 I(h * c)"
# [1] "4 I(F * h * F)"
# [1] "5 I(h * b)"
# [1] "6 I(F * c * F)"
# [1] "7 I(h * F)"
# [1] "8 I(c * F)"
# [1] "9 h"
# [1] "10 I(F * b * c)"
# [1] "11 I(b * c)"
# [1] "12 I(F * b * F)"
# [1] "13 I(b * F)"
# [1] "14 I(b^3)"
#
# Call:
# lm(formula = pca_4 ~ F + I(F^2) + c + b + I(b^2), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.35486 -0.09508  0.01865  0.08688  0.33840
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.4097     0.0333 -12.305 4.48e-14 ***
# F            -2.5398     0.9469  -2.682  0.01120 *
# I(F^2)       -2.4065     1.4430  -1.668  0.10457
# c             0.7626     0.2177   3.502  0.00131 **
# b             0.3660     0.6978   0.525  0.60329
# I(b^2)       -4.9089     3.5044  -1.401  0.17034
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1596 on 34 degrees of freedom
# Multiple R-squared:  0.6047,	Adjusted R-squared:  0.5466
# F-statistic:  10.4 on 5 and 34 DF,  p-value: 4.082e-06

# %%
cands <- names(tData)[1:4]
tLOOs <- LOO.plot(Emulators = TestEm6, which.emulator = 1, ParamNames = cands, Obs = tObs2[1], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm6, which.emulator = 2, ParamNames = cands, Obs = tObs2[2], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm6, which.emulator = 3, ParamNames = cands, Obs = tObs2[3], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm6, which.emulator = 4, ParamNames = cands, Obs = tObs2[4], ObsErr = 0.)#tLOOs <- 
tLOOs <- LOO.plot(Emulators = TestEm6, which.emulator = 5, ParamNames = cands, Obs = tObs2[5], ObsErr = 0.)#tLOOs <-
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
Timps6 <- matrix(rep(t(Timps5),1), ncol=ncol(Timps5), byrow=TRUE)
system.time(Timps6[NROY5,] <- ImplausibilityMOGP(NewData=Xp[NROY5,], Emulator=TestEm6, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr))
# Out:
#    user  system elapsed
#   0.823   4.984   2.057

# %%
ImpData_wave6 = cbind(Xp, Timps6)

# %%
valmax6 = 0 #how many outputs can be above the implausibility cut off?
ImpListM6 = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave6, nEms=TestEm6$mogp$n_emulators, whichMax=valmax6+1)
NROY6 <- which(rowSums(Timps6 <= cutoff_vec[1]) >= TestEm6$mogp$n_emulators -valmax6)
ratio6 <- length(NROY6)/dim(Xp)[1]
ratio6
# Out:
# [1] 7.5e-05

# %%
imp.layoutm11(ImpListM6,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",length(NROY6)/dim(Xp)[1],sep=""), side=1)
# Out:
# plot without title

# %%
length(NROY6)
# Out:
# [1] 75

# %%
colMeans(rangeUnscale(Xp[NROY6,], my_bounds))
# Out:
#        h        F        c        b
#  1.04244 10.87491 12.71549 10.23945

# %% [markdown]
# ## K-means

# %%
library(ClusterR)
# Out:
# Warning message:
# “package ‘ClusterR’ was built under R version 3.6.3”Loading required package: gtools
# Warning message:
# “package ‘gtools’ was built under R version 3.6.3”
# Attaching package: ‘gtools’
#
# The following object is masked from ‘package:pracma’:
#
#     logit

# %%
preProcValues <- preProcess(Xp[NROY5,], method = c("center", "scale"))
normalizeddata <- predict(preProcValues, Xp[NROY5,])

# %%
opt_km = Optimal_Clusters_KMeans(normalizeddata, 
                                 criterion = "silhouette", 
                                 max_clusters=10,
                                 plot_clusters = TRUE)
# Out:
# plot without title

# %%
classif <- kmeans(normalizeddata, centers=3, iter.max=100, nstart=100)
kmcenters <- unPreProc(preProcValues, data.frame(classif$centers))
candidates <- rangeUnscale(kmcenters, my_bounds)
candidates
# Out:
#   h         F         c         b
# 1 1.0532221  9.867436  9.056659 10.520146
# 2 0.8074277 10.062773 11.458736  9.295226
# 3 1.1107144 12.130353 17.100514 10.480709

# %%
nrow(rangeUnscale(unPreProc(preProcValues, normalizeddata[classif$cluster==1,]), my_bounds))
# Out:
# [1] 79

# %%
library(xtable)

print.xtable(xtable(candidates))
# Out:
# Attaching package: ‘xtable’
#
# The following object is masked from ‘package:spam’:
#
#     display
# % latex table generated in R 3.6.1 by xtable 1.8-4 package
# % Thu Feb 17 16:32:55 2022
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & h & F & c & b \\
#   \hline
# 1 & 1.05 & 9.87 & 9.06 & 10.52 \\
#   2 & 0.81 & 10.06 & 11.46 & 9.30 \\
#   3 & 1.11 & 12.13 & 17.10 & 10.48 \\
#    \hline
# \end{tabular}
# \end{table}

# %% [markdown]
# # Ensemble of plausible simulations

# %%
### check if Kmeans centers are in NROY6
imps_kmeans <- ImplausibilityMOGP(NewData=kmcenters, Emulator=TestEm5, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
which(rowSums(imps_kmeans <= cutoff_vec[1]) >= TestEm5$mogp$n_emulators -valmax5)
# Out:
# [1] 1 2 3

# %%
testpoints <- rangeUnscale(kmcenters, my_bounds)[rowSums(imps_kmeans <= cutoff_vec[1]) >= TestEm5$mogp$n_emulators -valmax5,]

# %%
write.csv(testpoints,"/gpfswork/rech/omr/udu91zn/HighTune_R/Data/JAMES/finaltestpoints_newPCA_PhysPrior.csv", row.names = FALSE)

# %% [markdown]
# ## summary of the HM

# %%
NROYs <- 100 * c(ratio1, ratio2, ratio3, ratio4, ratio5)
NbSim <- c(40, nrow(designpoints), nrow(designpoints2), nrow(designpoints3), nrow(designpoints4))

# %%
data.frame(NROYs, NbSim)
# Out:
#   NROYs   NbSim
# 1 25.5731 40
# 2  3.1812 40
# 3  0.5890 40
# 4  0.0379 40
# 5  0.0183 40

# %%
print.xtable(xtable(data.frame(NROYs, NbSim)))
# Out:
# % latex table generated in R 3.6.1 by xtable 1.8-4 package
# % Thu Feb 17 16:33:15 2022
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrr}
#   \hline
#  & NROYs & NbSim \\
#   \hline
# 1 & 25.57 & 40.00 \\
#   2 & 3.18 & 40.00 \\
#   3 & 0.59 & 40.00 \\
#   4 & 0.04 & 40.00 \\
#   5 & 0.02 & 40.00 \\
#    \hline
# \end{tabular}
# \end{table}

# %%
sum(NbSim)
# Out:
# [1] 200
